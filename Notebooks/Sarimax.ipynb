# %% [markdown]
# # Indicator vs Monthly Return Testing
#
# This notebook loads a JSON file containing indicator values and a monthly return variable, then automatically generates scatter plots of each indicator vs the monthly return.

# %%
import itertools
import json
import matplotlib.pyplot as plt
import numpy as np 
import os
import pandas as pd 
import warnings
from pathlib import Path
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
from sklearn.model_selection import cross_val_score
# For ARIMA model
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
# For ADF test (Augmented Dickey-Fuller)
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import kpss
# For ACF and PACF plots
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
# Suppress warnings to keep your notebook output clean
warnings.filterwarnings("ignore")

# Ensure matplotlib plots render inline in the notebook
# %matplotlib inline

# %%
print(os.getcwd())
# Out:
# c:\Users\micha\OneDrive\Desktop\TUE\HTT\HTTStockIndustryRankingTool\Notebooks

# %%
Path.cwd().parent
# Out:
# WindowsPath('c:/Users/micha/OneDrive/Desktop/TUE/HTT/HTTStockIndustryRankingTool')

# %%
path = Path.cwd().parent / "Data" / "oil_industry_data.json"
jdf = pd.read_json(path)
jdf
# Out:
#             XOM                                                CVX  SHEL  TTE  \
# 2025-12-31  NaN                                                NaN   NaN  NaN
# 2025-09-30  NaN  {'BOED': 6609000, 'OCF/BOED': 3502.79921319412...   NaN  NaN
# 2025-06-30  NaN  {'BOED': 3346500, 'OCF/BOED': 4113.25265202450...   NaN  NaN
# 2024-12-31  NaN  {'BOED': 3338000, 'OCF/BOED': 9434.39185140802...   NaN  NaN
# 2025-03-31  NaN  {'BOED': 13412000, 'OCF/BOED': 386.89233522218...   NaN  NaN
# ...         ...                                                ...   ...  ...
# 1996-09-30  NaN                                                NaN   NaN  NaN
# 1996-06-30  NaN                                                NaN   NaN  NaN
# 1996-03-31  NaN                                                NaN   NaN  NaN
# 1995-12-31  NaN                                                NaN   NaN  NaN
# 1995-09-30  NaN                                                NaN   NaN  NaN
#
#             PBR  PBR.A  BP  EQNR   E  SU  ...  CRT  PVL  PRT  USEG  \
# 2025-12-31  NaN    NaN NaN   NaN NaN NaN  ...  NaN  NaN  NaN   NaN
# 2025-09-30  NaN    NaN NaN   NaN NaN NaN  ...  NaN  NaN  NaN   NaN
# 2025-06-30  NaN    NaN NaN   NaN NaN NaN  ...  NaN  NaN  NaN   NaN
# 2024-12-31  NaN    NaN NaN   NaN NaN NaN  ...  NaN  NaN  NaN   NaN
# 2025-03-31  NaN    NaN NaN   NaN NaN NaN  ...  NaN  NaN  NaN   NaN
# ...         ...    ...  ..   ...  ..  ..  ...  ...  ...  ...   ...
# 1996-09-30  NaN    NaN NaN   NaN NaN NaN  ...  NaN  NaN  NaN   NaN
# 1996-06-30  NaN    NaN NaN   NaN NaN NaN  ...  NaN  NaN  NaN   NaN
# 1996-03-31  NaN    NaN NaN   NaN NaN NaN  ...  NaN  NaN  NaN   NaN
# 1995-12-31  NaN    NaN NaN   NaN NaN NaN  ...  NaN  NaN  NaN   NaN
# 1995-09-30  NaN    NaN NaN   NaN NaN NaN  ...  NaN  NaN  NaN   NaN
#
#                                                           MXC  \
# 2025-12-31                                               None
# 2025-09-30                                               None
# 2025-06-30                                               None
# 2024-12-31  {'BOED': 225.33, 'OCF/BOED': 13052.47858696134...
# 2025-03-31                                               None
# ...                                                       ...
# 1996-09-30                                               None
# 1996-06-30                                               None
# 1996-03-31                                               None
# 1995-12-31                                               None
# 1995-09-30                                               None
#
#                                                           CKX  EONR BRN  MTR  \
# 2025-12-31                                                NaN   NaN NaN  NaN
# 2025-09-30  {'BOED': 1000000, 'OCF/BOED': 0.336296, 'ROA':...   NaN NaN  NaN
# 2025-06-30  {'BOED': 150000, 'OCF/BOED': 0.626840000000000...   NaN NaN  NaN
# 2024-12-31  {'BOED': 22061.19, 'OCF/BOED': 9.2815029470305...   NaN NaN  NaN
# 2025-03-31  {'BOED': 100000, 'OCF/BOED': 1.186640000000000...   NaN NaN  NaN
# ...                                                       ...   ...  ..  ...
# 1996-09-30                                               None   NaN NaN  NaN
# 1996-06-30                                               None   NaN NaN  NaN
# 1996-03-31                                               None   NaN NaN  NaN
# 1995-12-31                                               None   NaN NaN  NaN
# 1995-09-30                                                NaN   NaN NaN  NaN
#
#            TPET
# 2025-12-31  NaN
# 2025-09-30  NaN
# 2025-06-30  NaN
# 2024-12-31  NaN
# 2025-03-31  NaN
# ...         ...
# 1996-09-30  NaN
# 1996-06-30  NaN
# 1996-03-31  NaN
# 1995-12-31  NaN
# 1995-09-30  NaN
#
# [125 rows x 95 columns]

# %%
s = jdf.stack()
s = s[s.map(type).eq(dict)]

out = pd.json_normalize(s.values)
out.index = s.index
out = out.reset_index()
out.columns = ['Date', 'Ticker'] + list(out.columns[2:])
out = out.drop(columns='Date')
out
# Out:
#     Ticker        BOED       OCF/BOED       ROA  CostExpenses/BOED  \
# 0      NFG     53051.0    5182.202032  1.973143        7075.908088
# 1      COP    224000.0   88375.000000  6.550816       29205.357143
# 2     FANG    497156.0   17616.200951  2.341716       27677.429217
# 3      DVN    389000.0   17251.928021  8.361024        7275.064267
# 4      EXE     16164.0  283036.377134  6.430516      597191.289285
# ..     ...         ...            ...       ...                ...
# 765    CKX    100000.0       4.419620  8.743000           2.191770
# 766    CKX  21176000.0       0.020871  8.743000           0.010350
# 767    MXC    104401.0      11.141186  0.976244          29.401519
# 768    CKX  17610000.0       0.025097  8.743000           0.012446
# 769    CKX  80614000.0       0.005482  8.743000           0.002719
#
#      Stock/Oil ZScore          PGR  Monthly Return
# 0            2.825966    11.730000        8.880840
# 1            1.994985    21.739130       16.205524
# 2            2.364790    53.530000       12.146607
# 3            1.153904    -0.410000       20.229319
# 4            2.376671    90.672727       -6.895615
# ..                ...          ...             ...
# 765         -0.371745     0.000000       -4.316563
# 766         -0.371745   829.587357       -4.316563
# 767         -0.713093     0.000000        1.960771
# 768         -0.371745   674.070000       -4.316563
# 769         -0.371745  3445.000000       -4.316563
#
# [770 rows x 8 columns]

# %%
# Make sure oil_industry_data.json is in the same level as this notebook
with open(path) as f:
    oil_industry_data =  json.load(f)

oil_industry_data
# Out:
# {'XOM': {'2025-12-31': None,
#   '2025-09-30': None,
#   '2025-06-30': None,
#   '2024-12-31': None,
#   '2025-03-31': None,
#   '2024-09-30': None,
#   '2024-06-30': None,
#   '2023-12-31': None,
#   '2024-03-31': None,
#   '2023-09-30': None,
#   '2023-06-30': None,
#   '2022-12-31': None,
#   '2023-03-31': None,
#   '2022-09-30': None,
#   '2022-06-30': None,
#   '2021-12-31': None,
#   '2022-03-31': None,
#   '2020-12-31': None,
#   '2020-09-30': None,
#   '2020-06-30': None,
#   '2019-12-31': None,
#   '2020-03-31': None,
#   '2019-09-30': None,
#   '2019-06-30': None},
#  'CVX': {'2025-09-30': {'BOED': 6609000,
#    'OCF/BOED': 3502.799213194129,
#    'ROA': 1.0839170477272657,
#    'CostExpenses/BOED': 6704.796489635346,
#    'Stock/Oil ZScore': 1.8907107808119483,
#    'PGR': 7.22,
#    'Monthly Return': -1.2685841273981846},
#   '2025-06-30': {'BOED': 3346500,
#    'OCF/BOED': 4113.252652024503,
#    'ROA': 0.9927438003349015,
#    'CostExpenses/BOED': 12154.489765426564,
#    'Stock/Oil ZScore': 1.2948218978736037,
#    'PGR': 1.66,
#    'Monthly Return': 7.856689187130055},
#   '2024-12-31': {'BOED': 3338000,
#    'OCF/BOED': 9434.391851408029,
#    'ROA': 6.8736426686593655,
#    'CostExpenses/BOED': 52512.2828040743,
#    'Stock/Oil ZScore': 0.7074895899667164,
#    'PGR': 6.99,
#    'Monthly Return': 8.438964960876866},
#   '2025-03-31': {'BOED': 13412000,
#    'OCF/BOED': 386.8923352221891,
#    'ROA': 1.3650705741486835,
#    'CostExpenses/BOED': 3133.5371309275274,
#    'Stock/Oil ZScore': 1.5424031061481458,
#    'PGR': 0.21,
#    'Monthly Return': -15.314717742223738},
#   '2024-06-30': {'BOED': 3143500,
#    'OCF/BOED': 4174.646095116908,
#    'ROA': 1.7011709458111448,
#    'CostExpenses/BOED': 14043.263877843168,
#    'Stock/Oil ZScore': 0.2644766697289475,
#    'PGR': 11.83,
#    'Monthly Return': -7.5709313157146285},
#   '2024-03-31': {'BOED': 3346000,
#    'OCF/BOED': 2040.6455469216976,
#    'ROA': 2.1024188709387697,
#    'CostExpenses/BOED': 12191.87089061566,
#    'Stock/Oil ZScore': 0.2496272906677375,
#    'PGR': 12.32,
#    'Monthly Return': 2.8476204976891597},
#   '2023-09-30': {'BOED': 3028000,
#    'OCF/BOED': 7653.566710700132,
#    'ROA': 2.4726534231056316,
#    'CostExpenses/BOED': 14974.240422721268,
#    'Stock/Oil ZScore': 0.029410840138840367,
#    'PGR': 1.102,
#    'Monthly Return': -14.600888639676253},
#   '2023-06-30': {'BOED': 2968000,
#    'OCF/BOED': 4549.191374663073,
#    'ROA': 2.3870140083168176,
#    'CostExpenses/BOED': 13833.8948787062,
#    'Stock/Oil ZScore': 0.7945875103456351,
#    'PGR': -0.3358,
#    'Monthly Return': 1.2011504824151713},
#   '2022-12-31': {'BOED': 2999000,
#    'OCF/BOED': 16539.51317105702,
#    'ROA': 13.761645887415652,
#    'CostExpenses/BOED': 65547.84928309436,
#    'Stock/Oil ZScore': 0.6731989975723305,
#    'PGR': -3.23,
#    'Monthly Return': -5.006391623039912},
#   '2023-03-31': {'BOED': 2979000,
#    'OCF/BOED': 2418.5968445787175,
#    'ROA': 2.5691128080473336,
#    'CostExpenses/BOED': 13854.984894259818,
#    'Stock/Oil ZScore': 0.6115632868933909,
#    'PGR': -2.65,
#    'Monthly Return': -5.914430848556151},
#   '2022-09-30': {'BOED': 3027000,
#    'OCF/BOED': 12257.680872150644,
#    'ROA': 4.32402256145687,
#    'CostExpenses/BOED': 17124.21539478031,
#    'Stock/Oil ZScore': -0.44518007075612015,
#    'PGR': -0.23,
#    'Monthly Return': 29.84616991517959},
#   '2022-06-30': {'BOED': 3051000,
#    'OCF/BOED': 7157.32546705998,
#    'ROA': 4.505768872898703,
#    'CostExpenses/BOED': 17292.363159619796,
#    'Stock/Oil ZScore': -1.3541043896395082,
#    'PGR': -4.68,
#    'Monthly Return': 8.309149537095717},
#   '2021-12-31': {'BOED': 3099000,
#    'OCF/BOED': 9418.199419167473,
#    'ROA': 6.52305508589559,
#    'CostExpenses/BOED': 45442.40077444337,
#    'Stock/Oil ZScore': -0.837979531901456,
#    'PGR': 0.518,
#    'Monthly Return': 15.61107939796997},
#   '2022-03-31': {'BOED': 3060000,
#    'OCF/BOED': 2632.3529411764707,
#    'ROA': 2.5131701519385823,
#    'CostExpenses/BOED': 14810.130718954248,
#    'Stock/Oil ZScore': -0.8010122229771176,
#    'PGR': -1.95,
#    'Monthly Return': 6.251916207822243},
#   '2021-09-30': {'BOED': 3028000,
#    'OCF/BOED': 6515.52179656539,
#    'ROA': 2.546801807058196,
#    'CostExpenses/BOED': 12105.350066050198,
#    'Stock/Oil ZScore': -1.3713818172810126,
#    'PGR': 2.48,
#    'Monthly Return': 12.597355491032047},
#   '2021-06-30': {'BOED': 3124000,
#    'OCF/BOED': 3569.1421254801535,
#    'ROA': 1.2693261286788629,
#    'CostExpenses/BOED': 10619.398207426377,
#    'Stock/Oil ZScore': -1.1810683841593608,
#    'PGR': 4.62,
#    'Monthly Return': -2.6541969843173976},
#   '2021-03-31': {'BOED': 3121000,
#    'OCF/BOED': 1344.440884331945,
#    'ROA': 0.5698441929276418,
#    'CostExpenses/BOED': 9564.88305030439,
#    'Stock/Oil ZScore': -0.6525493200056478,
#    'PGR': -3.52,
#    'Monthly Return': 4.466080890289717},
#   '2020-06-30': {'BOED': 3086000,
#    'OCF/BOED': 1556.0596241088788,
#    'ROA': -3.701830324570395,
#    'CostExpenses/BOED': 7806.545690213869,
#    'Stock/Oil ZScore': 0.29791259638547385,
#    'PGR': 1.63,
#    'Monthly Return': 0.6611946502972216},
#   '2019-12-31': {'BOED': 3058000,
#    'OCF/BOED': 8931.98168737737,
#    'ROA': 1.2315312431558199,
#    'CostExpenses/BOED': 46102.02746893394,
#    'Stock/Oil ZScore': -0.5310551911612835,
#    'PGR': 4.36,
#    'Monthly Return': -7.587248964436397},
#   '2020-03-31': {'BOED': 3235000,
#    'OCF/BOED': 1459.659969088099,
#    'ROA': 1.520637831305957,
#    'CostExpenses/BOED': 8456.259659969088,
#    'Stock/Oil ZScore': 2.3653901627482767,
#    'PGR': 6.48,
#    'Monthly Return': 24.275456591396324},
#   '2019-09-30': {'BOED': 4069333.33,
#    'OCF/BOED': 5322.001970283422,
#    'ROA': 1.0057028810658892,
#    'CostExpenses/BOED': 7880.160556913631,
#    'Stock/Oil ZScore': -0.31067771975135916,
#    'PGR': 6.04,
#    'Monthly Return': 1.9898720274230748},
#   '2019-06-30': {'BOED': 2950000,
#    'OCF/BOED': 4691.525423728814,
#    'ROA': 1.6824424139629042,
#    'CostExpenses/BOED': 11157.627118644068,
#    'Stock/Oil ZScore': -0.41733830214335904,
#    'PGR': 7.82,
#    'Monthly Return': -5.687287981563503},
#   '2018-12-31': {'BOED': 2930000,
#    'OCF/BOED': 10449.829351535836,
#    'ROA': 5.839370053926724,
#    'CostExpenses/BOED': 49748.80546075085,
#    'Stock/Oil ZScore': -0.2880719649582238,
#    'PGR': 7.4,
#    'Monthly Return': 9.704705838392266},
#   '2019-03-31': {'BOED': 3038000,
#    'OCF/BOED': 1664.5819618169849,
#    'ROA': 1.031505905166875,
#    'CostExpenses/BOED': 10284.068466096116,
#    'Stock/Oil ZScore': -0.6732957716167145,
#    'PGR': 6.52,
#    'Monthly Return': -2.2410976354730026},
#   '2018-09-30': {'BOED': 2956000,
#    'OCF/BOED': 7262.178619756428,
#    'ROA': 1.5771260219948091,
#    'CostExpenses/BOED': 12952.638700947226,
#    'Stock/Oil ZScore': -1.428127386000113,
#    'PGR': 8.78,
#    'Monthly Return': -7.26747128214052},
#   '2018-06-30': {'BOED': 2826000,
#    'OCF/BOED': 4210.1910828025475,
#    'ROA': 1.3216815480229056,
#    'CostExpenses/BOED': 13209.837225760793,
#    'Stock/Oil ZScore': -1.2059907726329164,
#    'PGR': 1.65,
#    'Monthly Return': -3.0451867566533704}},
#  'SHEL': None,
#  'TTE': None,
#  'PBR': None,
#  'PBR.A': None,
#  'BP': None,
#  'EQNR': None,
#  'E': None,
#  'SU': None,
#  'IMO': None,
#  'CVE': None,
#  'EC': None,
#  'YPF': None,
#  'NFG': {'2025-12-31': {'BOED': 53051,
#    'OCF/BOED': 5182.202032006937,
#    'ROA': 1.9731427940775192,
#    'CostExpenses/BOED': 7075.908088443196,
#    'Stock/Oil ZScore': 2.825965906205209,
#    'PGR': 11.73,
#    'Monthly Return': 8.88084040365845},
#   '2025-09-30': {'BOED': 201552,
#    'OCF/BOED': 5457.782606969913,
#    'ROA': 5.946757831997417,
#    'CostExpenses/BOED': 7264.041041517822,
#    'Stock/Oil ZScore': 3.088965471323187,
#    'PGR': 8.7515,
#    'Monthly Return': -13.954745388663907},
#   '2025-06-30': {'BOED': 233600,
#    'OCF/BOED': 3691.25,
#    'ROA': 1.773800164808623,
#    'CostExpenses/BOED': 1291.001712328767,
#    'Stock/Oil ZScore': 2.4414171977698302,
#    'PGR': 162.3,
#    'Monthly Return': 3.600520018780786},
#   '2024-12-31': {'BOED': 150000,
#    'OCF/BOED': 1467.2533333333333,
#    'ROA': 0.5419054603486042,
#    'CostExpenses/BOED': 3088.6066666666666,
#    'Stock/Oil ZScore': 0.25365521140109354,
#    'PGR': 0,
#    'Monthly Return': 18.984826490602508},
#   '2024-09-30': {'BOED': 178667,
#    'OCF/BOED': 5966.188495916986,
#    'ROA': 0.9316723899819346,
#    'CostExpenses/BOED': 9711.28412073858,
#    'Stock/Oil ZScore': 0.370665402137993,
#    'PGR': 5.18,
#    'Monthly Return': 1.0889265849634846},
#   '2024-06-30': {'BOED': 100000,
#    'OCF/BOED': 8680.15,
#    'ROA': -0.6385775701721381,
#    'CostExpenses/BOED': 4688.82,
#    'Stock/Oil ZScore': -0.6937510520411387,
#    'PGR': 0,
#    'Monthly Return': 8.448642518159096},
#   '2023-12-31': {'BOED': 7529,
#    'OCF/BOED': 35986.718023641915,
#    'ROA': 1.5489970762127057,
#    'CostExpenses/BOED': 42270.02257935981,
#    'Stock/Oil ZScore': -0.6324631869650804,
#    'PGR': 9.4,
#    'Monthly Return': -6.796882186976626},
#   '2024-03-31': {'BOED': 150000,
#    'OCF/BOED': 3908.4066666666668,
#    'ROA': 1.916232810208568,
#    'CostExpenses/BOED': 2528.7733333333335,
#    'Stock/Oil ZScore': -0.7948581051257964,
#    'PGR': 0,
#    'Monthly Return': 5.866927459157176},
#   '2023-09-30': {'BOED': 170000,
#    'OCF/BOED': 7276.911764705882,
#    'ROA': 5.759070367355615,
#    'CostExpenses/BOED': 8344.847058823529,
#    'Stock/Oil ZScore': -1.1503392751256503,
#    'PGR': -98.13,
#    'Monthly Return': -2.2153630413647902},
#   '2023-06-30': {'BOED': 175704,
#    'OCF/BOED': 6005.053954377817,
#    'ROA': 1.1425213331504378,
#    'CostExpenses/BOED': 1562.9012429995903,
#    'Stock/Oil ZScore': -0.533655671719814,
#    'PGR': 9.22,
#    'Monthly Return': 3.9524886630114366},
#   '2022-12-31': {'BOED': 21.92,
#    'OCF/BOED': 14933348.540145984,
#    'ROA': 2.0859347744794845,
#    'CostExpenses/BOED': 18452965.328467153,
#    'Stock/Oil ZScore': -0.36192748061896807,
#    'PGR': 6.51,
#    'Monthly Return': -7.140596951167231},
#   '2023-03-31': {'BOED': 161075,
#    'OCF/BOED': 4415.39034611206,
#    'ROA': 1.7682405027988355,
#    'CostExpenses/BOED': 3078.5907186093436,
#    'Stock/Oil ZScore': -0.3927580374355269,
#    'PGR': 7.1,
#    'Monthly Return': -12.677520710930402},
#   '2022-09-30': {'BOED': 160975,
#    'OCF/BOED': 5047.498058704768,
#    'ROA': 7.168214529862357,
#    'CostExpenses/BOED': 8599.260754775587,
#    'Stock/Oil ZScore': -0.5502267576052664,
#    'PGR': 7.66,
#    'Monthly Return': 4.126717984033576},
#   '2021-12-31': {'BOED': 38851.6,
#    'OCF/BOED': 4413.795056059467,
#    'ROA': 1.7443702778762669,
#    'CostExpenses/BOED': 8671.406068218555,
#    'Stock/Oil ZScore': -0.08530771430980154,
#    'PGR': 7.05,
#    'Monthly Return': -4.332187231260567},
#   '2022-03-31': {'BOED': 153890,
#    'OCF/BOED': 2765.735265449347,
#    'ROA': 2.1438501846823512,
#    'CostExpenses/BOED': 2958.957697056339,
#    'Stock/Oil ZScore': -0.8699859826829979,
#    'PGR': -4.8,
#    'Monthly Return': -1.324604010607458},
#   '2021-09-30': {'BOED': 149511,
#    'OCF/BOED': 5294.279350683228,
#    'ROA': 4.871473879159927,
#    'CostExpenses/BOED': 7717.164623338751,
#    'Stock/Oil ZScore': -0.7691060022579383,
#    'PGR': 35.6,
#    'Monthly Return': 14.62301291073698},
#   '2021-06-30': {'BOED': 151299,
#    'OCF/BOED': 4440.2805041672445,
#    'ROA': 1.1995963197120136,
#    'CostExpenses/BOED': 1614.8619620750962,
#    'Stock/Oil ZScore': -0.6798522037207002,
#    'PGR': 42.31,
#    'Monthly Return': 0.9569217211503576},
#   '2020-12-31': {'BOED': 36296,
#    'OCF/BOED': 5640.924619792815,
#    'ROA': 1.1048748943056907,
#    'CostExpenses/BOED': 9606.678421864668,
#    'Stock/Oil ZScore': -0.31799121970416216,
#    'PGR': 36.16,
#    'Monthly Return': 13.396558879075238},
#   '2021-03-31': {'BOED': 100000,
#    'OCF/BOED': 4171.33,
#    'ROA': 1.580122243190083,
#    'CostExpenses/BOED': 3370.76,
#    'Stock/Oil ZScore': -0.3193080373331783,
#    'PGR': 39.9,
#    'Monthly Return': 4.660936479121122},
#   '2020-06-30': {'BOED': 6492,
#    'OCF/BOED': 96098.27479975355,
#    'ROA': 0.5794365348430991,
#    'CostExpenses/BOED': 37372.4584103512,
#    'Stock/Oil ZScore': 0.534019299352519,
#    'PGR': 2.38,
#    'Monthly Return': 6.105416701669556},
#   '2019-12-31': {'BOED': 1646.575,
#    'OCF/BOED': 101877.53366837223,
#    'ROA': 1.291890470914673,
#    'CostExpenses/BOED': 179869.12226895223,
#    'Stock/Oil ZScore': -0.8197426167285629,
#    'PGR': 5.07,
#    'Monthly Return': -7.04770128294146},
#   '2020-03-31': {'BOED': 6422,
#    'OCF/BOED': 60883.21395203986,
#    'ROA': -1.5810611330818871,
#    'CostExpenses/BOED': 80298.19370912488,
#    'Stock/Oil ZScore': 3.0054564945990796,
#    'PGR': 6.34,
#    'Monthly Return': 7.347807728740839},
#   '2019-06-30': {'BOED': 92973,
#    'OCF/BOED': 6136.781646284405,
#    'ROA': 1.0061634276567817,
#    'CostExpenses/BOED': 2628.4297591773957,
#    'Stock/Oil ZScore': -0.4338258725070972,
#    'PGR': 24.39,
#    'Monthly Return': -12.499998877474955},
#   '2018-12-31': {'BOED': 22484,
#    'OCF/BOED': 4642.056573563423,
#    'ROA': 1.6593049086719613,
#    'CostExpenses/BOED': 17754.18075075609,
#    'Stock/Oil ZScore': 0.03998858864486749,
#    'PGR': 22.64,
#    'Monthly Return': 14.009372949986581},
#   '2019-03-31': {'BOED': 84108,
#    'OCF/BOED': 4052.3493603462216,
#    'ROA': 1.4428310353202554,
#    'CostExpenses/BOED': 4746.100252056879,
#    'Stock/Oil ZScore': -0.21559578314457054,
#    'PGR': 15.09,
#    'Monthly Return': -6.164510183942628},
#   '2018-09-30': {'BOED': 83895,
#    'OCF/BOED': 7334.203468621491,
#    'ROA': 0.6294224818876413,
#    'CostExpenses/BOED': 12789.14118839025,
#    'Stock/Oil ZScore': -1.1092457401385494,
#    'PGR': -7.48,
#    'Monthly Return': -3.405259139241035},
#   '2018-06-30': {'BOED': 79622,
#    'OCF/BOED': 7727.80136143277,
#    'ROA': 1.0549700934182085,
#    'CostExpenses/BOED': 13475.484162668608,
#    'Stock/Oil ZScore': -1.1036349393212455,
#    'PGR': -1.78,
#    'Monthly Return': 4.966016252018074},
#   '2017-12-31': {'BOED': 1843.84,
#    'OCF/BOED': 371240.4547032281,
#    'ROA': 3.4298399912153665,
#    'CostExpenses/BOED': 581907.8661922944,
#    'Stock/Oil ZScore': -0.552527963230406,
#    'PGR': -10.61,
#    'Monthly Return': -9.761465803971072},
#   '2018-03-31': {'BOED': 80684,
#    'OCF/BOED': 8483.813395468742,
#    'ROA': 1.5528931674357558,
#    'CostExpenses/BOED': 13298.113628476525,
#    'Stock/Oil ZScore': -0.8761349937362853,
#    'PGR': -4.23,
#    'Monthly Return': -0.23324206078795878},
#   '2017-06-30': {'BOED': 81103,
#    'OCF/BOED': 8439.983724399837,
#    'ROA': 1.0177064978363042,
#    'CostExpenses/BOED': 13229.41198229412,
#    'Stock/Oil ZScore': 0.6614653254124047,
#    'PGR': -6.09,
#    'Monthly Return': 5.426182231361718},
#   '2016-12-31': {'BOED': 20506,
#    'OCF/BOED': 33380.86413732566,
#    'ROA': 1.5703363484964012,
#    'CostExpenses/BOED': 52323.466302545596,
#    'Stock/Oil ZScore': 0.031615954469599465,
#    'PGR': 18.0,
#    'Monthly Return': 4.890505998491945}},
#  'TGS': None,
#  'DEC': None,
#  'SLNG': {'2025-09-30': {'BOED': 100000,
#    'OCF/BOED': 79.34,
#    'ROA': 1.2841699373407698,
#    'CostExpenses/BOED': 195.32,
#    'Stock/Oil ZScore': -0.9376315301999597,
#    'PGR': 0,
#    'Monthly Return': 9.174313832990853},
#   '2025-06-30': None,
#   '2025-03-31': {'BOED': 100000,
#    'OCF/BOED': 10.25,
#    'ROA': -1.9239104261979292,
#    'CostExpenses/BOED': 194.01,
#    'Stock/Oil ZScore': -0.9384524059988688,
#    'PGR': 0,
#    'Monthly Return': 14.226805583261816},
#   '2024-12-31': None,
#   '2024-09-30': None,
#   '2024-06-30': None,
#   '2024-03-31': None,
#   '2023-12-31': None,
#   '2023-09-30': {'BOED': 100000,
#    'OCF/BOED': 53.8,
#    'ROA': -0.255293958042993,
#    'CostExpenses/BOED': 157.92,
#    'Stock/Oil ZScore': -1.0403183120224586,
#    'PGR': 0,
#    'Monthly Return': 15.529408174402574},
#   '2023-06-30': None,
#   '2023-03-31': {'BOED': 100000,
#    'OCF/BOED': 0.93,
#    'ROA': 1.2470233644322248,
#    'CostExpenses/BOED': 258.29,
#    'Stock/Oil ZScore': -1.0344713000413113,
#    'PGR': 0,
#    'Monthly Return': -7.671238424451686},
#   '2022-12-31': None,
#   '2022-09-30': {'BOED': 100000,
#    'OCF/BOED': 115.38,
#    'ROA': -0.2947968881368198,
#    'CostExpenses/BOED': 247.97,
#    'Stock/Oil ZScore': -0.8225230527770512,
#    'PGR': 0,
#    'Monthly Return': -9.689922767163736},
#   '2022-06-30': {'BOED': 100000,
#    'OCF/BOED': 45.87,
#    'ROA': -2.488892970714179,
#    'CostExpenses/BOED': 256.87,
#    'Stock/Oil ZScore': -1.0875009308666153,
#    'PGR': 0,
#    'Monthly Return': 1.7326775327312123},
#   '2022-03-31': None,
#   '2021-12-31': None,
#   '2021-09-30': None,
#   '2021-06-30': {'BOED': 100000,
#    'OCF/BOED': 26.11,
#    'ROA': -1.13943300724062,
#    'CostExpenses/BOED': 181.46,
#    'Stock/Oil ZScore': -0.5995123165193376,
#    'PGR': 0,
#    'Monthly Return': -31.457283393002676},
#   '2021-03-31': {'BOED': 100000,
#    'OCF/BOED': 25.63,
#    'ROA': 0.2165975617303051,
#    'CostExpenses/BOED': 176.63,
#    'Stock/Oil ZScore': -0.7310068678668405,
#    'PGR': 0,
#    'Monthly Return': 15.99999886971933},
#   '2020-12-31': {'BOED': 100000,
#    'OCF/BOED': 13.36,
#    'ROA': -8.412087706846961,
#    'CostExpenses/BOED': 495.33,
#    'Stock/Oil ZScore': -0.9976784093742773,
#    'PGR': 0,
#    'Monthly Return': 12.727269259366123},
#   '2020-09-30': {'BOED': 100000,
#    'OCF/BOED': 24.67,
#    'ROA': -2.697132163269435,
#    'CostExpenses/BOED': 114.52,
#    'Stock/Oil ZScore': -0.9503768939573137,
#    'PGR': 0,
#    'Monthly Return': -10.156249854480844},
#   '2020-06-30': {'BOED': 100000,
#    'OCF/BOED': 43.23,
#    'ROA': -4.243352530327166,
#    'CostExpenses/BOED': 89.75,
#    'Stock/Oil ZScore': -1.0055564705736797,
#    'PGR': 0,
#    'Monthly Return': 8.962267333818868},
#   '2020-03-31': {'BOED': 100000,
#    'OCF/BOED': 3.49,
#    'ROA': -1.2245611989037262,
#    'CostExpenses/BOED': 144.71,
#    'Stock/Oil ZScore': -0.9330759879227608,
#    'PGR': 0,
#    'Monthly Return': 33.333333333333336},
#   '2019-12-31': {'BOED': 2774,
#    'OCF/BOED': 1481.97548666186,
#    'ROA': -6.3270819033279455,
#    'CostExpenses/BOED': 18926.099495313625,
#    'Stock/Oil ZScore': -0.9067364657179334,
#    'PGR': 17.11,
#    'Monthly Return': -21.91488882490478},
#   '2019-09-30': {'BOED': 100000,
#    'OCF/BOED': 37.21,
#    'ROA': -3.668751640276441,
#    'CostExpenses/BOED': 137.68,
#    'Stock/Oil ZScore': -0.7274401948493402,
#    'PGR': 0,
#    'Monthly Return': -26.61538490882287},
#   '2019-06-30': {'BOED': 100000,
#    'OCF/BOED': 48.79,
#    'ROA': -1.446639887091521,
#    'CostExpenses/BOED': 118.18,
#    'Stock/Oil ZScore': -0.8321582588223925,
#    'PGR': 0,
#    'Monthly Return': -22.499995955399037},
#   '2018-09-30': {'BOED': 100000,
#    'OCF/BOED': -14.7,
#    'ROA': -17.01388888888889,
#    'CostExpenses/BOED': 100.16,
#    'Stock/Oil ZScore': -0.91923150534501,
#    'PGR': 0,
#    'Monthly Return': -19.178087896109595},
#   '2018-06-30': {'BOED': 100000,
#    'OCF/BOED': -1.67,
#    'ROA': -10.270912101990438,
#    'CostExpenses/BOED': 107.91,
#    'Stock/Oil ZScore': -0.6324097517412661,
#    'PGR': 16.45,
#    'Monthly Return': -21.599998474121094},
#   '2017-03-31': {'BOED': 100000,
#    'OCF/BOED': 4.28,
#    'ROA': -7.365096233321526,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': 0.36963249834782747,
#    'PGR': 0,
#    'Monthly Return': -11.627912005583651},
#   '2018-03-31': {'BOED': 100000,
#    'OCF/BOED': -15.14,
#    'ROA': -9.068934920294955,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': -0.635670943218957,
#    'PGR': 0,
#    'Monthly Return': -33.63636334080342},
#   '2017-12-31': {'BOED': 100000,
#    'OCF/BOED': -36.82,
#    'ROA': 2.928254062550279,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': -0.359939810846499,
#    'PGR': 0,
#    'Monthly Return': -9.999998410542807},
#   '2017-09-30': {'BOED': 100000,
#    'OCF/BOED': -20.36,
#    'ROA': -2.8348688873139616,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': -0.14781205903512554,
#    'PGR': 0,
#    'Monthly Return': -9.37499837018552},
#   '2017-06-30': {'BOED': 100000,
#    'OCF/BOED': 4.28,
#    'ROA': -2.8457032299672167,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': 0.21869196995528875,
#    'PGR': 0,
#    'Monthly Return': 1.694913656104499},
#   '2016-12-31': {'BOED': 100000,
#    'OCF/BOED': 4.28,
#    'ROA': -4.815735925842189,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': -0.1555307976754113,
#    'PGR': 0,
#    'Monthly Return': 19.354843919656936},
#   '2016-09-30': {'BOED': 100000,
#    'OCF/BOED': 4.28,
#    'ROA': -7.188450264361833,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': 0.6997382056067046,
#    'PGR': 0,
#    'Monthly Return': -33.33333498901784},
#   '2016-06-30': {'BOED': 100000,
#    'OCF/BOED': 23.67,
#    'ROA': 0.4038404963761333,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': 0.8772411023402652,
#    'PGR': 0,
#    'Monthly Return': 49.0566002087647},
#   '2016-03-31': {'BOED': 100000,
#    'OCF/BOED': 23.67,
#    'ROA': -7.815761650445957,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': 0.5707720022378783,
#    'PGR': 0,
#    'Monthly Return': 40.33149404151118},
#   '2015-12-31': {'BOED': 120000,
#    'OCF/BOED': 19.725,
#    'ROA': -9.376457782615457,
#    'CostExpenses/BOED': 245.21666666666667,
#    'Stock/Oil ZScore': 0.9972338087093624,
#    'PGR': -3.63,
#    'Monthly Return': 10.476192314338334},
#   '2015-09-30': None,
#   '2015-06-30': {'BOED': 100000,
#    'OCF/BOED': -22.09,
#    'ROA': 1.2650031220369558,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': 1.9554949252687028,
#    'PGR': 0,
#    'Monthly Return': -15.686269193280335},
#   '2014-12-31': {'BOED': 100000,
#    'OCF/BOED': -22.09,
#    'ROA': -10.928469043325473,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': 2.6081423309945726,
#    'PGR': 0,
#    'Monthly Return': -19.168180459317472},
#   '2014-09-30': {'BOED': 100000,
#    'OCF/BOED': -0.71,
#    'ROA': -4.602270116263039,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': 1.878041971401128,
#    'PGR': 0,
#    'Monthly Return': -22.40215764635748},
#   '2014-06-30': {'BOED': 100000,
#    'OCF/BOED': 4.84,
#    'ROA': -2.9490497010796823,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': 1.165407013546797,
#    'PGR': 0,
#    'Monthly Return': -2.794118410163251},
#   '2014-03-31': {'BOED': 120000,
#    'OCF/BOED': -17.783333333333335,
#    'ROA': 1.2354093891113573,
#    'CostExpenses/BOED': 245.21666666666667,
#    'Stock/Oil ZScore': 1.2653900350095006,
#    'PGR': 50.1,
#    'Monthly Return': -9.425624007086686},
#   '2013-09-30': {'BOED': 100000,
#    'OCF/BOED': -2.47,
#    'ROA': 1.971122292714942,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': 1.3622814211189027,
#    'PGR': 0,
#    'Monthly Return': 26.939348466938306},
#   '2013-06-30': {'BOED': 100000,
#    'OCF/BOED': 18.48,
#    'ROA': 2.378076062639821,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': 1.4992090338129045,
#    'PGR': 0,
#    'Monthly Return': 6.629051905169534},
#   '2013-03-31': {'BOED': 100000,
#    'OCF/BOED': 12.59,
#    'ROA': 3.841148859041688,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': 0.6187862441964331,
#    'PGR': 0,
#    'Monthly Return': 19.193857824916012},
#   '2012-09-30': None,
#   '2012-06-30': {'BOED': 100000,
#    'OCF/BOED': -20.91,
#    'ROA': 2.239543308815457,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': 0.48040710902656686,
#    'PGR': 0,
#    'Monthly Return': 4.9411773681640625},
#   '2012-03-31': {'BOED': 100000,
#    'OCF/BOED': -7.29,
#    'ROA': 0.9290681502086231,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': 0.3628390126694434,
#    'PGR': 0,
#    'Monthly Return': -9.638554562953372},
#   '2011-12-31': {'BOED': 100000,
#    'OCF/BOED': 10.52,
#    'ROA': -14.341309927962243,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': 0.6350641484354342,
#    'PGR': 0,
#    'Monthly Return': -9.448819415007154},
#   '2011-09-30': None,
#   '2011-06-30': None,
#   '2011-03-31': {'BOED': 100000,
#    'OCF/BOED': 5.52,
#    'ROA': -4.978399506274429,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': -0.3302642099372513,
#    'PGR': 0,
#    'Monthly Return': 9.890109122348903},
#   '2010-12-31': None,
#   '2010-09-30': {'BOED': 100000,
#    'OCF/BOED': -6.72,
#    'ROA': -4.978399506274429,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': -0.13258226838495438,
#    'PGR': 0,
#    'Monthly Return': 7.327589706277551},
#   '2010-06-30': {'BOED': 100000,
#    'OCF/BOED': -8.49,
#    'ROA': -4.978399506274429,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': -0.145555723874099,
#    'PGR': 0,
#    'Monthly Return': 7.177038350599668},
#   '2010-03-31': None,
#   '2009-12-31': {'BOED': 100000,
#    'OCF/BOED': -8.49,
#    'ROA': -4.978399506274429,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': -0.09989495687724802,
#    'PGR': 0,
#    'Monthly Return': -3.097342191955019},
#   '2009-09-30': {'BOED': 100000,
#    'OCF/BOED': -8.49,
#    'ROA': -4.978399506274429,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': 0.10174922459805638,
#    'PGR': 0,
#    'Monthly Return': 1.2766047245027552},
#   '2009-06-30': {'BOED': 100000,
#    'OCF/BOED': -8.49,
#    'ROA': -4.978399506274429,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': -0.04180942418379138,
#    'PGR': 0,
#    'Monthly Return': -4.265398987862234},
#   '2009-03-31': None,
#   '2008-12-31': {'BOED': 100000,
#    'OCF/BOED': -8.49,
#    'ROA': -4.978399506274429,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': 0.36491563978949215,
#    'PGR': 0,
#    'Monthly Return': 12.432426859463526},
#   '2008-09-30': {'BOED': 100000,
#    'OCF/BOED': -8.49,
#    'ROA': -4.978399506274429,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': 0.04855603532697606,
#    'PGR': 0,
#    'Monthly Return': -11.214957297079053},
#   '2008-06-30': {'BOED': 100000,
#    'OCF/BOED': -8.49,
#    'ROA': -4.978399506274429,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': 0.31491278409141915,
#    'PGR': 0,
#    'Monthly Return': -20.545456626198508},
#   '2008-03-31': None,
#   '2007-12-31': {'BOED': 100000,
#    'OCF/BOED': -8.49,
#    'ROA': -4.978399506274429,
#    'CostExpenses/BOED': 294.26,
#    'Stock/Oil ZScore': 0.4468941417112178,
#    'PGR': 0,
#    'Monthly Return': 4.999995231628418},
#   '1999-09-30': {'BOED': 32752000,
#    'OCF/BOED': -0.02592208109428432,
#    'ROA': -4.978399506274429,
#    'CostExpenses/BOED': 0.8984489496824621,
#    'Stock/Oil ZScore': 2.8117693422583976,
#    'PGR': 1558.33,
#    'Monthly Return': -19.245773836943645}},
#  'SKYQ': None,
#  'COP': {'2025-12-31': {'BOED': 224000,
#    'OCF/BOED': 88375.0,
#    'ROA': 6.550816391802458,
#    'CostExpenses/BOED': 29205.35714285714,
#    'Stock/Oil ZScore': 1.994984985064348,
#    'PGR': 21.73913043478261,
#    'Monthly Return': 16.205524084625225},
#   '2024-06-30': {'BOED': 1860500,
#    'OCF/BOED': 5323.300188121472,
#    'ROA': 2.426193303748151,
#    'CostExpenses/BOED': 3516.2590701424347,
#    'Stock/Oil ZScore': 1.034303662439199,
#    'PGR': 6.95,
#    'Monthly Return': -3.7068573591077993},
#   '2023-12-31': {'BOED': 1826000,
#    'OCF/BOED': 10933.734939759037,
#    'ROA': 11.422584546098996,
#    'CostExpenses/BOED': 3582.694414019715,
#    'Stock/Oil ZScore': 1.5769832322764026,
#    'PGR': 5.063,
#    'Monthly Return': -5.126219064343347},
#   '2024-03-31': {'BOED': 1902000,
#    'OCF/BOED': 2620.925341745531,
#    'ROA': 2.6754625162562404,
#    'CostExpenses/BOED': 3439.5373291272344,
#    'Stock/Oil ZScore': 1.4990743777391784,
#    'PGR': 6.14,
#    'Monthly Return': -5.3387929297078545},
#   '2018-09-30': {'BOED': 1252250,
#    'OCF/BOED': 7307.646236773807,
#    'ROA': 2.6376211803390213,
#    'CostExpenses/BOED': 5224.196446396486,
#    'Stock/Oil ZScore': -0.7610158761418035,
#    'PGR': -11.07,
#    'Monthly Return': -19.90470874192886},
#   '2018-06-30': {'BOED': 1258000,
#    'OCF/BOED': 4563.593004769476,
#    'ROA': 2.3790182197980734,
#    'CostExpenses/BOED': 5200.317965023847,
#    'Stock/Oil ZScore': -0.9416687486356976,
#    'PGR': -16.91,
#    'Monthly Return': 4.059583565527439},
#   '2017-12-31': {'BOED': 1377000,
#    'OCF/BOED': 5139.433551198257,
#    'ROA': -1.1654535045391348,
#    'CostExpenses/BOED': 4750.907770515613,
#    'Stock/Oil ZScore': -1.1020378290230635,
#    'PGR': -12.24,
#    'Monthly Return': 1.673763865998317}},
#  'CNQ': None,
#  'EOG': {'2025-03-31': {'BOED': 1090400,
#    'OCF/BOED': 2099.2296404988997,
#    'ROA': 3.113958537312162,
#    'CostExpenses/BOED': 3494.1305942773292,
#    'Stock/Oil ZScore': 1.43497097578399,
#    'PGR': 5.99,
#    'Monthly Return': -9.0391699544703},
#   '2024-09-30': {'BOED': 1401067,
#    'OCF/BOED': 6694.897531666937,
#    'ROA': 3.625056878507508,
#    'CostExpenses/BOED': 2766.4629885651434,
#    'Stock/Oil ZScore': 1.353502536940177,
#    'PGR': 7.73,
#    'Monthly Return': 9.076754112214504},
#   '2024-06-30': {'BOED': 1047500,
#    'OCF/BOED': 5529.355608591885,
#    'ROA': 3.7369538298248717,
#    'CostExpenses/BOED': 3718.3770883054895,
#    'Stock/Oil ZScore': 0.5815270347925957,
#    'PGR': 7.93,
#    'Monthly Return': 0.6967260962722311},
#   '2024-03-31': {'BOED': 1028800,
#    'OCF/BOED': 2821.7340590979784,
#    'ROA': 3.9936601482275202,
#    'CostExpenses/BOED': 3744.167962674961,
#    'Stock/Oil ZScore': 0.6200233806915291,
#    'PGR': 9.1,
#    'Monthly Return': 0.4211577102880653},
#   '2023-12-31': {'BOED': 984658,
#    'OCF/BOED': 11516.689043302345,
#    'ROA': 17.315365848097226,
#    'CostExpenses/BOED': 14810.218370236164,
#    'Stock/Oil ZScore': 0.8333435001578824,
#    'PGR': 8.42,
#    'Monthly Return': -7.492872883816378},
#   '2023-09-30': {'BOED': 970800,
#    'OCF/BOED': 8483.724763081995,
#    'ROA': 4.650949664352647,
#    'CostExpenses/BOED': 3764.936135146271,
#    'Stock/Oil ZScore': 0.06866380569213466,
#    'PGR': 2.76,
#    'Monthly Return': -2.316772516043883},
#   '2023-03-31': {'BOED': 943000,
#    'OCF/BOED': 3451.749734888653,
#    'ROA': 4.931139549055454,
#    'CostExpenses/BOED': 3681.86638388123,
#    'Stock/Oil ZScore': 0.31714694876624566,
#    'PGR': 1.689,
#    'Monthly Return': -5.468968295393636},
#   '2022-12-31': {'BOED': 908219,
#    'OCF/BOED': 12214.014461269804,
#    'ROA': 18.754683232215804,
#    'CostExpenses/BOED': 17326.21757527645,
#    'Stock/Oil ZScore': 0.44949746457631484,
#    'PGR': 9.59,
#    'Monthly Return': -0.13276569896596738},
#   '2022-09-30': {'BOED': 1210533.33,
#    'OCF/BOED': 6318.702517674586,
#    'ROA': 7.049176278805542,
#    'CostExpenses/BOED': 3245.6768455933384,
#    'Stock/Oil ZScore': -0.2650721674865321,
#    'PGR': 11.09,
#    'Monthly Return': 31.60841605578514},
#   '2022-03-31': {'BOED': 883300,
#    'OCF/BOED': 937.3938639193932,
#    'ROA': 1.023702653752264,
#    'CostExpenses/BOED': 3891.090229819993,
#    'Stock/Oil ZScore': -0.8277360067389039,
#    'PGR': 13.4,
#    'Monthly Return': 6.621976167971228},
#   '2021-09-30': {'BOED': 844400,
#    'OCF/BOED': 6661.53481762198,
#    'ROA': 2.9457656300441193,
#    'CostExpenses/BOED': 3900.9947891994316,
#    'Stock/Oil ZScore': -1.1554051734967963,
#    'PGR': 17.93,
#    'Monthly Return': 18.693396002170473},
#   '2021-03-31': {'BOED': 778900,
#    'OCF/BOED': 2400.821671588137,
#    'ROA': 1.871665146111526,
#    'CostExpenses/BOED': 3546.026447554243,
#    'Stock/Oil ZScore': -0.9248121331630106,
#    'PGR': -10.89,
#    'Monthly Return': 14.522033477579942},
#   '2020-09-30': {'BOED': 954667,
#    'OCF/BOED': 4071.576790650562,
#    'ROA': -0.11974675955289753,
#    'CostExpenses/BOED': 2355.7952668312614,
#    'Stock/Oil ZScore': -1.6001903903208727,
#    'PGR': -14.17,
#    'Monthly Return': 13.794330664471019},
#   '2020-03-31': {'BOED': 874100,
#    'OCF/BOED': 2957.327536895092,
#    'ROA': 0.026571657755772665,
#    'CostExpenses/BOED': 5331.197803454982,
#    'Stock/Oil ZScore': 0.014741062879492757,
#    'PGR': 12.99,
#    'Monthly Return': 33.59166691956613},
#   '2019-09-30': {'BOED': 807100,
#    'OCF/BOED': 7875.078676743898,
#    'ROA': 1.683316380819155,
#    'CostExpenses/BOED': 4306.152893073969,
#    'Stock/Oil ZScore': -0.8493130755981677,
#    'PGR': 11.4,
#    'Monthly Return': -0.8406547390277339},
#   '2019-06-30': {'BOED': 812800,
#    'OCF/BOED': 5283.356299212598,
#    'ROA': 2.3714836476376195,
#    'CostExpenses/BOED': 4388.359990157481,
#    'Stock/Oil ZScore': -0.3708827646728742,
#    'PGR': 15.75,
#    'Monthly Return': -19.14897932673004}},
#  'OXY': None,
#  'FANG': {'2025-12-31': {'BOED': 497156,
#    'OCF/BOED': 17616.20095100934,
#    'ROA': 2.341716038784672,
#    'CostExpenses/BOED': 27677.429217388504,
#    'Stock/Oil ZScore': 2.3647897006095433,
#    'PGR': 53.53,
#    'Monthly Return': 12.146606987577277},
#   '2025-09-30': {'BOED': 503750,
#    'OCF/BOED': 12734.491315136476,
#    'ROA': 1.3357301247818614,
#    'CostExpenses/BOED': 5335.980148883375,
#    'Stock/Oil ZScore': 1.5862866404045712,
#    'PGR': 3.64,
#    'Monthly Return': 2.1453521467908345},
#   '2025-06-30': {'BOED': 485873,
#    'OCF/BOED': 8298.464825170364,
#    'ROA': 0.971629529753548,
#    'CostExpenses/BOED': 5225.645384699294,
#    'Stock/Oil ZScore': 1.326757188258927,
#    'PGR': 88.21,
#    'Monthly Return': 0.7933188229419154},
#   '2025-03-31': {'BOED': 475944,
#    'OCF/BOED': 4948.061116433866,
#    'ROA': 2.0052521907915395,
#    'CostExpenses/BOED': 4990.082866891903,
#    'Stock/Oil ZScore': 1.5288782790967368,
#    'PGR': -5.8,
#    'Monthly Return': -9.419563065413099},
#   '2024-12-31': {'BOED': 336954,
#    'OCF/BOED': 19032.27146732195,
#    'ROA': 4.9604707840456514,
#    'CostExpenses/BOED': 19794.986852804836,
#    'Stock/Oil ZScore': 1.6169056835191022,
#    'PGR': 34.0,
#    'Monthly Return': -4.175052802363753},
#   '2024-09-30': {'BOED': 321054,
#    'OCF/BOED': 12683.224628878632,
#    'ROA': 1.0023271023772948,
#    'CostExpenses/BOED': 6027.023491375283,
#    'Stock/Oil ZScore': 2.0394492497947803,
#    'PGR': 13.94,
#    'Monthly Return': 4.3561664059848},
#   '2024-06-30': {'BOED': 266017.5,
#    'OCF/BOED': 10762.449838826393,
#    'ROA': 2.348682549036114,
#    'CostExpenses/BOED': 4988.3936207204415,
#    'Stock/Oil ZScore': 1.871912477890687,
#    'PGR': 7.53,
#    'Monthly Return': -3.5638944232081537},
#   '2024-03-31': {'BOED': 273341,
#    'OCF/BOED': 4880.350916986475,
#    'ROA': 2.5867295385651734,
#    'CostExpenses/BOED': 4057.203273566717,
#    'Stock/Oil ZScore': 1.6737122447095172,
#    'PGR': 9.7,
#    'Monthly Return': 0.2820615618774117},
#   '2023-09-30': {'BOED': 260264,
#    'OCF/BOED': 16506.316663080564,
#    'ROA': 3.2621483831865663,
#    'CostExpenses/BOED': 3842.2524820951035,
#    'Stock/Oil ZScore': 0.1628295259224178,
#    'PGR': 15.23,
#    'Monthly Return': 2.1306634196613783},
#   '2023-06-30': {'BOED': 257261,
#    'OCF/BOED': 11420.308558234634,
#    'ROA': 1.9171752698182822,
#    'CostExpenses/BOED': 3572.2476395567146,
#    'Stock/Oil ZScore': 0.40390777396814,
#    'PGR': 4.68,
#    'Monthly Return': 12.85372050649178},
#   '2023-03-31': {'BOED': 251378,
#    'OCF/BOED': 5668.75382889513,
#    'ROA': 2.580738700206604,
#    'CostExpenses/BOED': 3580.2655761442925,
#    'Stock/Oil ZScore': 0.26301974598710337,
#    'PGR': 6.23,
#    'Monthly Return': -7.046954729087177},
#   '2022-09-30': {'BOED': 222758,
#    'OCF/BOED': 21925.13849109796,
#    'ROA': 4.96581805980791,
#    'CostExpenses/BOED': 3694.5923378733874,
#    'Stock/Oil ZScore': -0.4803870980829691,
#    'PGR': 3.445,
#    'Monthly Return': 35.78779289126334},
#   '2022-06-30': {'BOED': 217735,
#    'OCF/BOED': 13589.914345419891,
#    'ROA': 6.038894575230297,
#    'CostExpenses/BOED': 3628.26371506648,
#    'Stock/Oil ZScore': -1.1355554405834496,
#    'PGR': -0.24,
#    'Monthly Return': 8.072310619233377},
#   '2022-03-31': {'BOED': 222833,
#    'OCF/BOED': 5618.557394999843,
#    'ROA': 3.338905319103339,
#    'CostExpenses/BOED': 3356.773906916839,
#    'Stock/Oil ZScore': -0.7851438833491984,
#    'PGR': 24.06,
#    'Monthly Return': -1.912400803673176},
#   '2021-09-30': {'BOED': 239761,
#    'OCF/BOED': 11582.367440909906,
#    'ROA': 2.8667343963956005,
#    'CostExpenses/BOED': 3111.4318008349983,
#    'Stock/Oil ZScore': -0.9238920743626603,
#    'PGR': 21.39,
#    'Monthly Return': 16.64435068926896},
#   '2021-06-30': {'BOED': 354696,
#    'OCF/BOED': 4448.88016780567,
#    'ROA': 1.3581972224648442,
#    'CostExpenses/BOED': 2046.8231950740917,
#    'Stock/Oil ZScore': -0.8564703978270175,
#    'PGR': 14.68,
#    'Monthly Return': -18.970905764715614},
#   '2021-03-31': {'BOED': 184200,
#    'OCF/BOED': 3387.6221498371337,
#    'ROA': 1.000181851245681,
#    'CostExpenses/BOED': 3327.904451682953,
#    'Stock/Oil ZScore': -1.0365213368659565,
#    'PGR': -5.3,
#    'Monthly Return': 7.628855384155561},
#   '2020-12-31': {'BOED': 180825,
#    'OCF/BOED': 11712.982165076732,
#    'ROA': -25.63709631647653,
#    'CostExpenses/BOED': 45839.90045624222,
#    'Stock/Oil ZScore': -1.4485910517418292,
#    'PGR': 6.42,
#    'Monthly Return': 42.23135941961543},
#   '2020-09-30': {'BOED': 300785,
#    'OCF/BOED': 5701.747095101152,
#    'ROA': -5.932835820895522,
#    'CostExpenses/BOED': 6569.47653639643,
#    'Stock/Oil ZScore': -1.8220481390900827,
#    'PGR': 0.0606,
#    'Monthly Return': 6.343719268357516},
#   '2020-06-30': {'BOED': 185992,
#    'OCF/BOED': 6306.722869800852,
#    'ROA': -11.766730589565816,
#    'CostExpenses/BOED': 16651.253817368488,
#    'Stock/Oil ZScore': -1.337494142051076,
#    'PGR': 13.9,
#    'Monthly Return': 7.506687557343886},
#   '2020-03-31': {'BOED': 201369,
#    'OCF/BOED': 4216.140518153241,
#    'ROA': -1.1630890276233643,
#    'CostExpenses/BOED': 8447.179059338825,
#    'Stock/Oil ZScore': -1.1163029931441169,
#    'PGR': 23.6,
#    'Monthly Return': 47.0746486775445},
#   '2019-06-30': {'BOED': 191229,
#    'OCF/BOED': 5454.193663095032,
#    'ROA': 1.4831498873826017,
#    'CostExpenses/BOED': 3189.892746393068,
#    'Stock/Oil ZScore': -0.22234378169776434,
#    'PGR': 152.37,
#    'Monthly Return': -11.92502903821278},
#   '2019-03-31': {'BOED': 262633,
#    'OCF/BOED': 1435.4631748485529,
#    'ROA': 0.04249713144362755,
#    'CostExpenses/BOED': 2075.1390723937966,
#    'Stock/Oil ZScore': -0.535520171814983,
#    'PGR': 155.96,
#    'Monthly Return': 5.178917775770637},
#   '2018-12-31': {'BOED': 104831.5,
#    'OCF/BOED': 14928.718944210472,
#    'ROA': 1.4215595480644563,
#    'CostExpenses/BOED': 11113.071929715781,
#    'Stock/Oil ZScore': -0.15808301850201323,
#    'PGR': 64.63,
#    'Monthly Return': 12.006465617400888},
#   '2018-09-30': {'BOED': 122975,
#    'OCF/BOED': 9375.889408416344,
#    'ROA': 1.600897318242072,
#    'CostExpenses/BOED': 2187.436470827404,
#    'Stock/Oil ZScore': -0.3566227862729063,
#    'PGR': 44.64,
#    'Monthly Return': -21.16226853929616},
#   '2018-06-30': {'BOED': 112592,
#    'OCF/BOED': 10240.514423760125,
#    'ROA': 2.4458342640160824,
#    'CostExpenses/BOED': 2184.879920420634,
#    'Stock/Oil ZScore': -0.27955489203358097,
#    'PGR': 46.27,
#    'Monthly Return': 1.6568926951887426},
#   '2018-03-31': {'BOED': 102607,
#    'OCF/BOED': 8664.126229204636,
#    'ROA': 1.9817899040084193,
#    'CostExpenses/BOED': 2066.13583868547,
#    'Stock/Oil ZScore': -0.033978345296107285,
#    'PGR': 66.54,
#    'Monthly Return': -1.802122086739422},
#   '2017-12-31': {'BOED': 79224,
#    'OCF/BOED': 11221.347066545492,
#    'ROA': 1.4741860764380388,
#    'CostExpenses/BOED': 7573.462587094819,
#    'Stock/Oil ZScore': 0.1297351857315549,
#    'PGR': 84.1,
#    'Monthly Return': -2.708898994641548},
#   '2017-09-30': {'BOED': 113372,
#    'OCF/BOED': 7841.442331439862,
#    'ROA': 1.0020352468752265,
#    'CostExpenses/BOED': 1399.0579684578204,
#    'Stock/Oil ZScore': -0.20260452842615065,
#    'PGR': 89.28,
#    'Monthly Return': 13.28092385181992},
#   '2017-06-30': {'BOED': 56910,
#    'OCF/BOED': 15621.156211562116,
#    'ROA': 2.335045105190904,
#    'CostExpenses/BOED': 2409.5238095238096,
#    'Stock/Oil ZScore': 0.05688007392558864,
#    'PGR': 108.83,
#    'Monthly Return': -0.8895562872398171},
#   '2017-03-31': {'BOED': 61610,
#    'OCF/BOED': 14429.475734458692,
#    'ROA': 2.1393943199836727,
#    'CostExpenses/BOED': 1928.5830222366499,
#    'Stock/Oil ZScore': 0.24609022699754213,
#    'PGR': 59.06,
#    'Monthly Return': 0.2313968173853339},
#   '2016-09-30': {'BOED': 44923,
#    'OCF/BOED': 19789.417447632615,
#    'ROA': -0.06325020988858887,
#    'CostExpenses/BOED': 3014.892148787926,
#    'Stock/Oil ZScore': 0.2538594526190312,
#    'PGR': 31.81,
#    'Monthly Return': -2.2995444631330315},
#   '2016-03-31': {'BOED': 153232,
#    'OCF/BOED': 5801.660227628694,
#    'ROA': -1.1183302247839675,
#    'CostExpenses/BOED': 751.0441683199332,
#    'Stock/Oil ZScore': 0.221509351112189,
#    'PGR': 26.432,
#    'Monthly Return': 10.76699781481594},
#   '2015-12-31': {'BOED': 33098,
#    'OCF/BOED': 26859.628980603058,
#    'ROA': -6.813091413554056,
#    'CostExpenses/BOED': 35863.25457731585,
#    'Stock/Oil ZScore': -0.04422541922372592,
#    'PGR': 69.96,
#    'Monthly Return': 5.291459425213008},
#   '2015-09-30': {'BOED': 136328,
#    'OCF/BOED': 6521.037497799425,
#    'ROA': -5.2407878981960545,
#    'CostExpenses/BOED': 8706.956751364356,
#    'Stock/Oil ZScore': -0.8338647812994325,
#    'PGR': 65.16,
#    'Monthly Return': 20.882382026744843},
#   '2015-06-30': {'BOED': 30302,
#    'OCF/BOED': 29337.997491914724,
#    'ROA': -6.693672121781212,
#    'CostExpenses/BOED': 9340.901590654083,
#    'Stock/Oil ZScore': -1.0921501833637406,
#    'PGR': 92.93,
#    'Monthly Return': -4.921738362190966}},
#  'EQT': None,
#  'WDS': None,
#  'TPL': {'2023-12-31': {'BOED': 10140,
#    'OCF/BOED': 41251.282051282054,
#    'ROA': 35.078320785750236,
#    'CostExpenses/BOED': 14353.254437869822,
#    'Stock/Oil ZScore': -0.9220996547531908,
#    'PGR': 10.06,
#    'Monthly Return': -8.634301523472407},
#   '2024-06-30': {'BOED': 24900,
#    'OCF/BOED': 9860.763052208835,
#    'ROA': 8.708753897845478,
#    'CostExpenses/BOED': 1570.7630522088352,
#    'Stock/Oil ZScore': -0.5802954384642381,
#    'PGR': 0.0441,
#    'Monthly Return': 13.028733316302768},
#   '2024-03-31': {'BOED': 24800,
#    'OCF/BOED': 5937.258064516129,
#    'ROA': 9.086699969027217,
#    'CostExpenses/BOED': 1536.3306451612902,
#    'Stock/Oil ZScore': -0.9730479352864548,
#    'PGR': 19.97,
#    'Monthly Return': 6.407067772644938},
#   '2023-09-30': {'BOED': 21800,
#    'OCF/BOED': 14076.055045871559,
#    'ROA': 9.781547236310336,
#    'CostExpenses/BOED': 1422.4311926605506,
#    'Stock/Oil ZScore': -1.0093586846782043,
#    'PGR': -6.6,
#    'Monthly Return': -8.894148417351072},
#   '2022-12-31': {'BOED': 9318,
#    'OCF/BOED': 47987.658295771624,
#    'ROA': 50.87169644882138,
#    'CostExpenses/BOED': 11280.854260570937,
#    'Stock/Oil ZScore': -0.8744587532668213,
#    'PGR': 14.66,
#    'Monthly Return': -4.3293730126303585},
#   '2023-03-31': {'BOED': 2169.86,
#    'OCF/BOED': 52895.11765736038,
#    'ROA': 9.062330214781246,
#    'CostExpenses/BOED': 19084.180546210355,
#    'Stock/Oil ZScore': -0.8699984279101118,
#    'PGR': 0.588,
#    'Monthly Return': -22.00680127453016}},
#  'DVN': {'2025-12-31': {'BOED': 389000,
#    'OCF/BOED': 17251.928020565552,
#    'ROA': 8.361024083040602,
#    'CostExpenses/BOED': 7275.064267352185,
#    'Stock/Oil ZScore': 1.1539043262432425,
#    'PGR': -0.41,
#    'Monthly Return': 20.22931922287652},
#   '2025-09-30': {'BOED': 390000,
#    'OCF/BOED': 4333.333333333333,
#    'ROA': 2.2004420101854523,
#    'CostExpenses/BOED': 7256.410256410257,
#    'Stock/Oil ZScore': 0.5450462111595323,
#    'PGR': 1.43,
#    'Monthly Return': 0.4563632921188277},
#   '2025-06-30': {'BOED': 388000,
#    'OCF/BOED': 3981.958762886598,
#    'ROA': 2.8639694170117873,
#    'CostExpenses/BOED': 7293.81443298969,
#    'Stock/Oil ZScore': 0.13372484083925035,
#    'PGR': 20.69,
#    'Monthly Return': 4.746933149560409},
#   '2025-03-31': {'BOED': 388000,
#    'OCF/BOED': 5005.154639175258,
#    'ROA': 1.5972581479565442,
#    'CostExpenses/BOED': 7293.81443298969,
#    'Stock/Oil ZScore': 0.3267775160901293,
#    'PGR': -3.893,
#    'Monthly Return': -9.19787437803177},
#   '2024-12-31': {'BOED': 737000,
#    'OCF/BOED': 8955.223880597016,
#    'ROA': 9.482108301354588,
#    'CostExpenses/BOED': 3839.89145183175,
#    'Stock/Oil ZScore': -0.14511055866894368,
#    'PGR': 12.5,
#    'Monthly Return': 5.835639954979698},
#   '2024-09-30': {'BOED': 330000,
#    'OCF/BOED': 5039.393939393939,
#    'ROA': 2.683144433797046,
#    'CostExpenses/BOED': 8575.757575757576,
#    'Stock/Oil ZScore': 0.5976171054976362,
#    'PGR': 6.71,
#    'Monthly Return': -1.9938727204917237},
#   '2024-06-30': {'BOED': 686000,
#    'OCF/BOED': 2237.6093294460643,
#    'ROA': 3.354264366902472,
#    'CostExpenses/BOED': 4125.364431486881,
#    'Stock/Oil ZScore': 0.5977524434760115,
#    'PGR': 5.21,
#    'Monthly Return': -6.7881644841223725},
#   '2024-03-31': {'BOED': 319000,
#    'OCF/BOED': 5448.275862068966,
#    'ROA': 2.38609976779566,
#    'CostExpenses/BOED': 8871.473354231975,
#    'Stock/Oil ZScore': 0.7904213664440292,
#    'PGR': 0.302,
#    'Monthly Return': -2.1982421670758123},
#   '2023-12-31': {'BOED': 658000,
#    'OCF/BOED': 9945.288753799392,
#    'ROA': 15.300122498979174,
#    'CostExpenses/BOED': 4300.911854103343,
#    'Stock/Oil ZScore': 0.7885271741397784,
#    'PGR': 7.87,
#    'Monthly Return': -7.637970455692095},
#   '2023-09-30': {'BOED': 656000,
#    'OCF/BOED': 2629.5731707317073,
#    'ROA': 3.753970545769564,
#    'CostExpenses/BOED': 4314.024390243902,
#    'Stock/Oil ZScore': 0.11840334229175481,
#    'PGR': 8.97,
#    'Monthly Return': -4.7798967399592245},
#   '2023-06-30': {'BOED': 322000,
#    'OCF/BOED': 4363.3540372670805,
#    'ROA': 2.954399486191394,
#    'CostExpenses/BOED': 8788.819875776397,
#    'Stock/Oil ZScore': 1.0671240611143327,
#    'PGR': 9.58,
#    'Monthly Return': 1.7583820334698914},
#   '2023-03-31': {'BOED': 320000,
#    'OCF/BOED': 5240.625,
#    'ROA': 4.248505550811273,
#    'CostExpenses/BOED': 8843.75,
#    'Stock/Oil ZScore': 0.9315554063922764,
#    'PGR': 11.48,
#    'Monthly Return': -8.85199707900743},
#   '2022-12-31': {'BOED': 299000,
#    'OCF/BOED': 28528.428093645485,
#    'ROA': 25.847621503158436,
#    'CostExpenses/BOED': 9464.882943143813,
#    'Stock/Oil ZScore': 1.3909028295125423,
#    'PGR': 6.64,
#    'Monthly Return': -6.958217091873846},
#   '2022-09-30': {'BOED': 602000,
#    'OCF/BOED': 3495.0166112956813,
#    'ROA': 8.035827991679756,
#    'CostExpenses/BOED': 4700.996677740864,
#    'Stock/Oil ZScore': 1.0832146146310933,
#    'PGR': 7.89,
#    'Monthly Return': 18.909052922578635},
#   '2022-06-30': {'BOED': 300000,
#    'OCF/BOED': 8926.666666666666,
#    'ROA': 8.32974045011641,
#    'CostExpenses/BOED': 9433.333333333334,
#    'Stock/Oil ZScore': -0.29314884902885036,
#    'PGR': 11.62,
#    'Monthly Return': 15.351110211929866},
#   '2022-03-31': {'BOED': 575000,
#    'OCF/BOED': 3194.782608695652,
#    'ROA': 4.541280191018459,
#    'CostExpenses/BOED': 4921.739130434783,
#    'Stock/Oil ZScore': 0.0771447016961292,
#    'PGR': 15.23,
#    'Monthly Return': 20.05751269219058},
#   '2021-12-31': {'BOED': 290000,
#    'OCF/BOED': 16893.103448275862,
#    'ROA': 13.379310344827585,
#    'CostExpenses/BOED': 9758.620689655172,
#    'Stock/Oil ZScore': 0.13291306655718405,
#    'PGR': 71.31,
#    'Monthly Return': 16.73100870744087},
#   '2021-09-30': {'BOED': 287000,
#    'OCF/BOED': 5567.94425087108,
#    'ROA': 3.979674217599848,
#    'CostExpenses/BOED': 9860.627177700348,
#    'Stock/Oil ZScore': -0.6111536892308937,
#    'PGR': 67.57,
#    'Monthly Return': 19.909886190942373},
#   '2021-06-30': {'BOED': 533000,
#    'OCF/BOED': 2050.656660412758,
#    'ROA': 1.2758534762023424,
#    'CostExpenses/BOED': 5309.568480300188,
#    'Stock/Oil ZScore': -1.0306060729206885,
#    'PGR': 58.16,
#    'Monthly Return': -4.04250351732322},
#   '2021-03-31': {'BOED': 268000,
#    'OCF/BOED': 2208.955223880597,
#    'ROA': 1.0412083883267342,
#    'CostExpenses/BOED': 10559.701492537313,
#    'Stock/Oil ZScore': -1.3153150442518429,
#    'PGR': 49.85,
#    'Monthly Return': 20.732244203269715},
#   '2020-12-31': {'BOED': 155000,
#    'OCF/BOED': 3819.3548387096776,
#    'ROA': -27.037933817594833,
#    'CostExpenses/BOED': 18258.064516129034,
#    'Stock/Oil ZScore': -1.5605872035865163,
#    'PGR': 2.52,
#    'Monthly Return': 37.444650737939355},
#   '2020-09-30': {'BOED': 326000,
#    'OCF/BOED': 1815.9509202453987,
#    'ROA': -0.8909548711989154,
#    'CostExpenses/BOED': 8680.981595092024,
#    'Stock/Oil ZScore': -1.9940130099419768,
#    'PGR': 0.31,
#    'Monthly Return': 18.60467670861662},
#   '2020-06-30': {'BOED': 148500,
#    'OCF/BOED': 3986.5319865319866,
#    'ROA': -6.469054745582698,
#    'CostExpenses/BOED': 19057.239057239058,
#    'Stock/Oil ZScore': -1.7925467359814686,
#    'PGR': 0.31,
#    'Monthly Return': 6.625234975337873},
#   '2019-12-31': {'BOED': 150000,
#    'OCF/BOED': 3946.6666666666665,
#    'ROA': -4.680323685937158,
#    'CostExpenses/BOED': 18866.666666666668,
#    'Stock/Oil ZScore': -1.1876388598740961,
#    'PGR': 13.85,
#    'Monthly Return': -12.129383677804602},
#   '2020-03-31': {'BOED': 163000,
#    'OCF/BOED': 3631.9018404907974,
#    'ROA': -16.295764536970566,
#    'CostExpenses/BOED': 17361.963190184048,
#    'Stock/Oil ZScore': -1.6522659613269541,
#    'PGR': 15.6,
#    'Monthly Return': 68.7410153231054},
#   '2019-09-30': {'BOED': 428000,
#    'OCF/BOED': 1878.5046728971963,
#    'ROA': 0.7572599694317077,
#    'CostExpenses/BOED': 6612.14953271028,
#    'Stock/Oil ZScore': -1.1830758416630125,
#    'PGR': 2.39231,
#    'Monthly Return': -7.024113557210824},
#   '2019-06-30': {'BOED': 145000,
#    'OCF/BOED': 5544.827586206897,
#    'ROA': 2.973151540633071,
#    'CostExpenses/BOED': 19517.241379310344,
#    'Stock/Oil ZScore': -0.9324268199591929,
#    'PGR': -1.4,
# ...
#    'OCF/BOED': 4266.666666666667,
#    'ROA': 0.3334773181960985,
#    'CostExpenses/BOED': 2957.4242230464256,
#    'Stock/Oil ZScore': -0.7555425283970635,
#    'PGR': -12.24,
#    'Monthly Return': 2.5714238719413016},
#   '2011-09-30': {'BOED': 254.01,
#    'OCF/BOED': 2504.7832762489666,
#    'ROA': 0.5198899962296302,
#    'CostExpenses/BOED': 2772.705798984292,
#    'Stock/Oil ZScore': -0.8802131626002728,
#    'PGR': -8.11,
#    'Monthly Return': 5.437123082132276},
#   '2010-12-31': None,
#   '2010-03-31': None,
#   '2010-06-30': None,
#   '2009-12-31': None,
#   '2009-09-30': None,
#   '2009-03-31': None,
#   '2008-12-31': None,
#   '2008-09-30': None,
#   '2008-03-31': None,
#   '2007-09-30': {'BOED': 150000,
#    'OCF/BOED': 7.75434,
#    'ROA': 0.9762440549943627,
#    'CostExpenses/BOED': 20.463653333333333,
#    'Stock/Oil ZScore': -0.7329442958775035,
#    'PGR': 0,
#    'Monthly Return': -7.766986117105033},
#   '2007-06-30': None,
#   '2007-03-31': {'BOED': 200.83333333333334,
#    'OCF/BOED': 5791.623236514522,
#    'ROA': 0.9762440549943627,
#    'CostExpenses/BOED': 15284.05643153527,
#    'Stock/Oil ZScore': -0.7130927825664836,
#    'PGR': -2.22,
#    'Monthly Return': 1.9607710715789402},
#   '2006-12-31': None,
#   '2006-09-30': None,
#   '2006-06-30': None,
#   '2006-03-31': None,
#   '2005-12-31': None,
#   '2005-09-30': None,
#   '2005-06-30': None,
#   '2005-03-31': None,
#   '2004-12-31': None,
#   '2004-09-30': None,
#   '2004-06-30': None,
#   '2003-12-31': None,
#   '2003-09-30': None,
#   '2003-06-30': None,
#   '2003-03-31': None,
#   '2002-12-31': None,
#   '2002-09-30': None,
#   '2002-06-30': None,
#   '2002-03-31': None,
#   '2001-12-31': None,
#   '2001-09-30': None,
#   '2001-06-30': None,
#   '2001-03-31': None,
#   '2000-12-31': None,
#   '2000-09-30': None,
#   '2000-03-31': None,
#   '2000-06-30': None,
#   '1999-12-31': None,
#   '1999-09-30': {'BOED': 37154000,
#    'OCF/BOED': 0.031306211982559076,
#    'ROA': 0.9762440549943627,
#    'CostExpenses/BOED': 0.08261689185552026,
#    'Stock/Oil ZScore': -0.7130927825664836,
#    'PGR': 1769.85,
#    'Monthly Return': 1.9607710715789402},
#   '1999-06-30': {'BOED': 29338000,
#    'OCF/BOED': 0.03964656759151953,
#    'ROA': 0.9762440549943627,
#    'CostExpenses/BOED': 0.10462703660781239,
#    'Stock/Oil ZScore': -0.7130927825664836,
#    'PGR': 1361.06,
#    'Monthly Return': 1.9607710715789402},
#   '1999-03-31': None,
#   '1998-12-31': {'BOED': 31556000,
#    'OCF/BOED': 0.03685989986056534,
#    'ROA': 0.9762440549943627,
#    'CostExpenses/BOED': 0.09727303840790975,
#    'Stock/Oil ZScore': -0.7130927825664836,
#    'PGR': 1434.8,
#    'Monthly Return': 1.9607710715789402},
#   '1998-09-30': None,
#   '1998-06-30': None,
#   '1998-03-31': {'BOED': 104401,
#    'OCF/BOED': 11.141186387103572,
#    'ROA': 0.9762440549943627,
#    'CostExpenses/BOED': 29.401519142536948,
#    'Stock/Oil ZScore': -0.7130927825664836,
#    'PGR': 0,
#    'Monthly Return': 1.9607710715789402},
#   '1997-12-31': None,
#   '1997-09-30': None,
#   '1997-06-30': None,
#   '1997-03-31': None,
#   '1996-12-31': None,
#   '1996-09-30': None,
#   '1996-06-30': None,
#   '1996-03-31': None,
#   '1995-12-31': None,
#   '1995-09-30': None},
#  'CKX': {'2025-09-30': {'BOED': 1000000,
#    'OCF/BOED': 0.336296,
#    'ROA': 0.867999547168795,
#    'CostExpenses/BOED': 0.119286,
#    'Stock/Oil ZScore': 0.15566745883430322,
#    'PGR': 0,
#    'Monthly Return': -7.450627451762616},
#   '2025-06-30': {'BOED': 150000,
#    'OCF/BOED': 0.62684,
#    'ROA': 0.8526713500530875,
#    'CostExpenses/BOED': -0.15822,
#    'Stock/Oil ZScore': -0.006566086637649581,
#    'PGR': 0,
#    'Monthly Return': 9.81308606964336},
#   '2024-12-31': {'BOED': 22061.19,
#    'OCF/BOED': 9.28150294703051,
#    'ROA': 1.3276428794310806,
#    'CostExpenses/BOED': 63.6471559331115,
#    'Stock/Oil ZScore': 0.20849016764788644,
#    'PGR': 51.31,
#    'Monthly Return': -9.682541508673365},
#   '2025-03-31': {'BOED': 100000,
#    'OCF/BOED': 1.18664,
#    'ROA': 0.609612940907585,
#    'CostExpenses/BOED': 2.36034,
#    'Stock/Oil ZScore': 0.0047808209136603495,
#    'PGR': 0,
#    'Monthly Return': -8.593087733137017},
#   '2024-09-30': None,
#   '2024-06-30': None,
#   '2024-03-31': {'BOED': 100000,
#    'OCF/BOED': -3.37838,
#    'ROA': -2.182247392530587,
#    'CostExpenses/BOED': 5.78455,
#    'Stock/Oil ZScore': -0.1196941288719821,
#    'PGR': 0,
#    'Monthly Return': 3.1460678973232112},
#   '2023-12-31': {'BOED': 14.58,
#    'OCF/BOED': 60147.66803840878,
#    'ROA': 0.7598889855457327,
#    'CostExpenses/BOED': 93537.79149519891,
#    'Stock/Oil ZScore': 0.19654454367119484,
#    'PGR': -26.1,
#    'Monthly Return': 3.3950584806187405},
#   '2023-09-30': {'BOED': 100000,
#    'OCF/BOED': 2.5242,
#    'ROA': 0.19658746995304227,
#    'CostExpenses/BOED': 2.55218,
#    'Stock/Oil ZScore': -0.4265912513327893,
#    'PGR': 0,
#    'Monthly Return': -5.106707943125829},
#   '2023-06-30': None,
#   '2023-03-31': {'BOED': 100000,
#    'OCF/BOED': -0.90391,
#    'ROA': -1.3284172817507545,
#    'CostExpenses/BOED': 5.08571,
#    'Stock/Oil ZScore': -0.8229016211914302,
#    'PGR': 0,
#    'Monthly Return': 4.029693554011338},
#   '2022-12-31': {'BOED': 12.93,
#    'OCF/BOED': 31994.663573085847,
#    'ROA': -7.44995785180457,
#    'CostExpenses/BOED': 227999.53596287704,
#    'Stock/Oil ZScore': -0.8717443493817099,
#    'PGR': -6.96,
#    'Monthly Return': -2.814067721995976},
#   '2022-09-30': {'BOED': 17.76,
#    'OCF/BOED': 9915.315315315314,
#    'ROA': -0.30050590750453393,
#    'CostExpenses/BOED': 24076.18243243243,
#    'Stock/Oil ZScore': -0.6996502341975277,
#    'PGR': -12.16,
#    'Monthly Return': -3.20219919210787},
#   '2022-06-30': {'BOED': 7.13,
#    'OCF/BOED': -19534.22159887798,
#    'ROA': -1.6288643443890332,
#    'CostExpenses/BOED': 86331.41654978962,
#    'Stock/Oil ZScore': -1.256535099854733,
#    'PGR': -17.01,
#    'Monthly Return': 0.628928069222531},
#   '2021-12-31': {'BOED': 13.89,
#    'OCF/BOED': -18982.9373650108,
#    'ROA': 4.804132632099736,
#    'CostExpenses/BOED': -22949.24406047516,
#    'Stock/Oil ZScore': -0.2973536281657818,
#    'PGR': -4.21,
#    'Monthly Return': 1.0714275678809637},
#   '2022-03-31': {'BOED': 14.6,
#    'OCF/BOED': -3296.3698630136987,
#    'ROA': 0.027781198329681824,
#    'CostExpenses/BOED': 12599.657534246575,
#    'Stock/Oil ZScore': -1.1717334039139258,
#    'PGR': -12.16,
#    'Monthly Return': 7.882682148300467},
#   '2021-09-30': {'BOED': 7.25,
#    'OCF/BOED': -8812.827586206897,
#    'ROA': 1.103157507395045,
#    'CostExpenses/BOED': -14366.068965517241,
#    'Stock/Oil ZScore': -0.3042481904376803,
#    'PGR': 21.68,
#    'Monthly Return': 7.180854953826691},
#   '2021-06-30': {'BOED': 23.17,
#    'OCF/BOED': -2762.9693569270607,
#    'ROA': 1.0331638435321038,
#    'CostExpenses/BOED': -929.046180405697,
#    'Stock/Oil ZScore': 0.1426334379054825,
#    'PGR': -25.58,
#    'Monthly Return': -7.315111560349992},
#   '2021-03-31': {'BOED': 16.62,
#    'OCF/BOED': -9083.93501805054,
#    'ROA': 2.5562664364547323,
#    'CostExpenses/BOED': -17656.49819494585,
#    'Stock/Oil ZScore': 0.9219338568046118,
#    'PGR': -52.52,
#    'Monthly Return': 2.625483842437094},
#   '2020-12-31': {'BOED': 13.82,
#    'OCF/BOED': 10142.18523878437,
#    'ROA': 2.079973661335992,
#    'CostExpenses/BOED': 21193.27062228654,
#    'Stock/Oil ZScore': 0.5097907524947208,
#    'PGR': -19.61,
#    'Monthly Return': 15.56256053224452},
#   '2020-09-30': {'BOED': 15.45,
#    'OCF/BOED': 11426.472491909386,
#    'ROA': 0.3066682359310111,
#    'CostExpenses/BOED': 5664.142394822006,
#    'Stock/Oil ZScore': 1.7453203785187217,
#    'PGR': -29.1,
#    'Monthly Return': -5.100002288818359},
#   '2020-06-30': {'BOED': 28.15,
#    'OCF/BOED': 3269.6980461811722,
#    'ROA': 1.303797819796907,
#    'CostExpenses/BOED': -546.891651865009,
#    'Stock/Oil ZScore': 0.7997102474172564,
#    'PGR': -7.86,
#    'Monthly Return': 16.707611785211466},
#   '2020-03-31': {'BOED': 17.41,
#    'OCF/BOED': 1248.879954049397,
#    'ROA': 0.36493640147779804,
#    'CostExpenses/BOED': 7147.386559448592,
#    'Stock/Oil ZScore': 4.3870321947084525,
#    'PGR': 19.31,
#    'Monthly Return': -5.294115403119256},
#   '2019-12-31': {'BOED': 31.855,
#    'OCF/BOED': 6112.415633338565,
#    'ROA': 1.5756187695153294,
#    'CostExpenses/BOED': 19452.67618898132,
#    'Stock/Oil ZScore': -0.35410098947316854,
#    'PGR': 3.3,
#    'Monthly Return': -0.21458696077492384},
#   '2019-09-30': {'BOED': 17.96,
#    'OCF/BOED': 4193.429844097996,
#    'ROA': 0.3669236060241805,
#    'CostExpenses/BOED': 9675.612472160356,
#    'Stock/Oil ZScore': 0.21174711231646323,
#    'PGR': 4.83,
#    'Monthly Return': -8.568647275723112},
#   '2019-06-30': None,
#   '2019-03-31': {'BOED': 25.89,
#    'OCF/BOED': -1545.384318269602,
#    'ROA': 0.6740194789276868,
#    'CostExpenses/BOED': 2476.4387794515255,
#    'Stock/Oil ZScore': -0.27583605243983134,
#    'PGR': -6.57,
#    'Monthly Return': 0.7992000187495606},
#   '2018-09-30': {'BOED': 29.54,
#    'OCF/BOED': 3320.5484089370348,
#    'ROA': 0.5501746740166739,
#    'CostExpenses/BOED': 6153.689911983751,
#    'Stock/Oil ZScore': -0.8099241165947246,
#    'PGR': -22.53,
#    'Monthly Return': 8.910886975623141},
#   '2018-06-30': {'BOED': 20.69,
#    'OCF/BOED': 248.04253262445624,
#    'ROA': 0.983765572446004,
#    'CostExpenses/BOED': 8034.412759787337,
#    'Stock/Oil ZScore': -0.4792986848088794,
#    'PGR': -29.95,
#    'Monthly Return': -5.405404924977025},
#   '2018-03-31': {'BOED': 38.56,
#    'OCF/BOED': -1133.5840248962654,
#    'ROA': 5.365831683693648,
#    'CostExpenses/BOED': -18186.877593360994,
#    'Stock/Oil ZScore': -0.26520298365362255,
#    'PGR': -43.89,
#    'Monthly Return': -0.2875822672487363},
#   '2017-12-31': {'BOED': 41.98,
#    'OCF/BOED': 9629.656979514055,
#    'ROA': 3.5511568836091,
#    'CostExpenses/BOED': 14374.845164363984,
#    'Stock/Oil ZScore': -0.15310537181051587,
#    'PGR': -7.35,
#    'Monthly Return': 0.785847317111686},
#   '2017-09-30': {'BOED': 57.04,
#    'OCF/BOED': 4853.523842917251,
#    'ROA': 0.3501940000212992,
#    'CostExpenses/BOED': 2047.335203366059,
#    'Stock/Oil ZScore': 0.47886023119375715,
#    'PGR': -8.64,
#    'Monthly Return': -4.245293667638501},
#   '2017-06-30': None,
#   '2017-03-31': {'BOED': 49,
#    'OCF/BOED': -1076.469387755102,
#    'ROA': 0.30776516621146804,
#    'CostExpenses/BOED': 3460.469387755102,
#    'Stock/Oil ZScore': 1.3055378648898455,
#    'PGR': 19.25,
#    'Monthly Return': -3.277301166867407},
#   '2016-12-31': {'BOED': 50.27,
#    'OCF/BOED': 5585.975731052317,
#    'ROA': 1.1837298149216233,
#    'CostExpenses/BOED': 13448.219614083946,
#    'Stock/Oil ZScore': 0.7008413227568847,
#    'PGR': -14.78,
#    'Monthly Return': 4.162900310201609},
#   '2016-09-30': {'BOED': 45.41,
#    'OCF/BOED': 4032.2836379652063,
#    'ROA': 0.1486320509985075,
#    'CostExpenses/BOED': 4254.745650737724,
#    'Stock/Oil ZScore': 1.2473404739165528,
#    'PGR': -24.29,
#    'Monthly Return': 2.181811877700011},
#   '2016-06-30': {'BOED': 54.1,
#    'OCF/BOED': 2132.5878003696857,
#    'ROA': 0.024855304877467177,
#    'CostExpenses/BOED': 2982.125693160813,
#    'Stock/Oil ZScore': 1.328176407419754,
#    'PGR': -32.42,
#    'Monthly Return': 1.4109335488367372},
#   '2016-03-31': None,
#   '2015-12-31': None,
#   '2015-09-30': None,
#   '2015-06-30': None,
#   '2015-03-31': None,
#   '2014-12-31': None,
#   '2014-09-30': None,
#   '2014-06-30': None,
#   '2014-03-31': {'BOED': 52.35,
#    'OCF/BOED': 7332.702960840496,
#    'ROA': 2.3874059114126625,
#    'CostExpenses/BOED': 2792.6456542502387,
#    'Stock/Oil ZScore': -0.4830531081580099,
#    'PGR': -11.54,
#    'Monthly Return': -1.1896858940552644},
#   '2013-12-31': {'BOED': 55.65,
#    'OCF/BOED': 21177.017070979335,
#    'ROA': 7.433128585319431,
#    'CostExpenses/BOED': 13390.601976639713,
#    'Stock/Oil ZScore': -0.5989604374852431,
#    'PGR': -42.22,
#    'Monthly Return': -1.8036023682161475},
#   '2013-09-30': {'BOED': 56.48,
#    'OCF/BOED': 13592.581444759207,
#    'ROA': 7.433128585319431,
#    'CostExpenses/BOED': 2936.8626062322946,
#    'Stock/Oil ZScore': -0.5703737873192725,
#    'PGR': -35.36,
#    'Monthly Return': 0.8742439914676546},
#   '2013-06-30': None,
#   '2013-03-31': {'BOED': 58.37,
#    'OCF/BOED': 4030.563645708412,
#    'ROA': 17.77133381325375,
#    'CostExpenses/BOED': 3319.89035463423,
#    'Stock/Oil ZScore': -0.7542419913870587,
#    'PGR': -50.82,
#    'Monthly Return': -0.13954755155904952},
#   '2011-12-31': {'BOED': 26.85,
#    'OCF/BOED': 37562.12290502793,
#    'ROA': 8.6564773397724,
#    'CostExpenses/BOED': 25111.098696461824,
#    'Stock/Oil ZScore': -1.2547194919952092,
#    'PGR': -7.85,
#    'Monthly Return': 1.497802461528661},
#   '2012-09-30': {'BOED': 92,
#    'OCF/BOED': 12249.847826086956,
#    'ROA': 3.5902566031036955,
#    'CostExpenses/BOED': 2264.836956521739,
#    'Stock/Oil ZScore': -0.823606508127746,
#    'PGR': 63.63,
#    'Monthly Return': -2.3222971077560475},
#   '2012-06-30': {'BOED': 72.79,
#    'OCF/BOED': 10791.825800247287,
#    'ROA': 3.5902566031036955,
#    'CostExpenses/BOED': 2502.4179145487014,
#    'Stock/Oil ZScore': -0.4659369603479208,
#    'PGR': 80.23,
#    'Monthly Return': 14.545460684961544},
#   '2012-03-31': None,
#   '2011-09-30': None,
#   '2011-06-30': None,
#   '2011-03-31': None,
#   '2010-12-31': None,
#   '2010-09-30': None,
#   '2010-06-30': None,
#   '2010-03-31': None,
#   '2009-12-31': None,
#   '2008-12-31': None,
#   '2009-09-30': None,
#   '2009-06-30': None,
#   '2009-03-31': None,
#   '2008-09-30': {'BOED': 120,
#    'OCF/BOED': 3683.016666666667,
#    'ROA': 8.743000416132197,
#    'CostExpenses/BOED': 1826.475,
#    'Stock/Oil ZScore': -1.119838854222899,
#    'PGR': -15.56,
#    'Monthly Return': -5.200001124707576},
#   '2008-06-30': {'BOED': 127.39,
#    'OCF/BOED': 3469.3618023392733,
#    'ROA': 8.743000416132197,
#    'CostExpenses/BOED': 1720.5196640238637,
#    'Stock/Oil ZScore': -1.6383934305802526,
#    'PGR': -10.87,
#    'Monthly Return': -6.365671775199554},
#   '2008-03-31': {'BOED': 118.13,
#    'OCF/BOED': 3741.318885973081,
#    'ROA': 8.743000416132197,
#    'CostExpenses/BOED': 1855.3881317192925,
#    'Stock/Oil ZScore': -1.318031749687603,
#    'PGR': 5.44,
#    'Monthly Return': 10.256433098258272},
#   '2003-12-31': {'BOED': 425.092,
#    'OCF/BOED': 1039.685526897707,
#    'ROA': 8.743000416132197,
#    'CostExpenses/BOED': 515.5989762216179,
#    'Stock/Oil ZScore': -0.3717450874678262,
#    'PGR': 15.93,
#    'Monthly Return': -4.316563350485659},
#   '2003-09-30': {'BOED': 100000,
#    'OCF/BOED': 4.41962,
#    'ROA': 8.743000416132197,
#    'CostExpenses/BOED': 2.19177,
#    'Stock/Oil ZScore': -0.3717450874678262,
#    'PGR': 0,
#    'Monthly Return': -4.316563350485659},
#   '2003-06-30': {'BOED': 100000,
#    'OCF/BOED': 4.41962,
#    'ROA': 8.743000416132197,
#    'CostExpenses/BOED': 2.19177,
#    'Stock/Oil ZScore': -0.3717450874678262,
#    'PGR': 0,
#    'Monthly Return': -4.316563350485659},
#   '2003-03-31': None,
#   '2002-12-31': None,
#   '2002-09-30': None,
#   '2002-06-30': None,
#   '2002-03-31': None,
#   '2001-12-31': None,
#   '2001-09-30': None,
#   '2001-06-30': None,
#   '2001-03-31': None,
#   '2000-12-31': None,
#   '2000-09-30': None,
#   '2000-06-30': None,
#   '2000-03-31': None,
#   '1999-12-31': None,
#   '1999-09-30': None,
#   '1999-06-30': None,
#   '1999-03-31': None,
#   '1998-12-31': {'BOED': 100000,
#    'OCF/BOED': 4.41962,
#    'ROA': 8.743000416132197,
#    'CostExpenses/BOED': 2.19177,
#    'Stock/Oil ZScore': -0.3717450874678262,
#    'PGR': 0,
#    'Monthly Return': -4.316563350485659},
#   '1998-09-30': {'BOED': 21176000,
#    'OCF/BOED': 0.020870891575368342,
#    'ROA': 8.743000416132197,
#    'CostExpenses/BOED': 0.010350255005666793,
#    'Stock/Oil ZScore': -0.3717450874678262,
#    'PGR': 829.587357,
#    'Monthly Return': -4.316563350485659},
#   '1998-06-30': None,
#   '1998-03-31': {'BOED': 17610000,
#    'OCF/BOED': 0.025097217490062464,
#    'ROA': 8.743000416132197,
#    'CostExpenses/BOED': 0.012446166950596253,
#    'Stock/Oil ZScore': -0.3717450874678262,
#    'PGR': 674.07,
#    'Monthly Return': -4.316563350485659},
#   '1997-12-31': {'BOED': 80614000,
#    'OCF/BOED': 0.0054824472176048826,
#    'ROA': 8.743000416132197,
#    'CostExpenses/BOED': 0.002718845361847818,
#    'Stock/Oil ZScore': -0.3717450874678262,
#    'PGR': 3445,
#    'Monthly Return': -4.316563350485659},
#   '1997-09-30': None,
#   '1997-06-30': None,
#   '1997-03-31': None,
#   '1996-12-31': None,
#   '1996-09-30': None,
#   '1996-06-30': None,
#   '1996-03-31': None,
#   '1995-12-31': None},
#  'EONR': None,
#  'BRN': None,
#  'MTR': None,
#  'TPET': None}

# %% [markdown]
# ## ARIMA Models

# %% [markdown]
# Basic Arima (not used)

# %%
def ARIMA_Stock_Analysis(ticker):
    # ==========================================
    # 1. Load Data & Extract Ticker 
    # ==========================================
    # Using the exact absolute path you provided
    oil_stock_data = oil_industry_data.get(ticker, {})
    records = []

    # Parse dates and Monthly Return, skipping nulls
    for date_str, metrics in oil_stock_data.items():
        if metrics is not None and "Monthly Return" in metrics:
            records.append({
                "Date": pd.to_datetime(date_str),
                "Monthly Return": metrics["Monthly Return"]
            })

    if not records:
        raise ValueError(f"No valid data found for {ticker}.")

    # Create DataFrame, set Date as index, sort chronologically
    df = pd.DataFrame(records).set_index("Date").sort_index()

    # Resample to Quarterly frequency to ensure an even time-series
    df = df.resample('QE').mean().interpolate()
    ts_data = df["Monthly Return"]

    print(f"Successfully loaded {len(ts_data)} valid quarterly data points for {ticker}.")

    # ==========================================
    # 2. Stationarity Check (ADF Test)
    # ==========================================
    print("\n--- Step 1: Stationarity Check (ADF Test) ---")
    adf_result = adfuller(ts_data)
    print(f"ADF Statistic: {adf_result[0]:.4f}")
    print(f"p-value: {adf_result[1]:.4f}")

    # Determine differencing parameter (d)
    d_val = 0 if adf_result[1] < 0.05 else 1
    print(f"-> Based on p-value, setting ARIMA differencing parameter (d) to: {d_val}")

    # ==========================================
    # 3. Autocorrelation Plots (ACF & PACF)
    # ==========================================
    print("\n--- Step 2: ACF & PACF Plots ---")
    fig, axes = plt.subplots(1, 2, figsize=(14, 4))
    plot_acf(ts_data, ax=axes[0], title="Autocorrelation (ACF) -> Determines 'q'")
    plot_pacf(ts_data, ax=axes[1], title="Partial Autocorr (PACF) -> Determines 'p'")
    plt.tight_layout()
    plt.show() 

    # ==========================================
    # 4. Fit the ARIMA Model
    # ==========================================
    print("\n--- Step 3: Fitting ARIMA Model ---")
    p, q = 1, 1 
    model = ARIMA(ts_data, order=(p, d_val, q))
    fitted_model = model.fit()

    print(fitted_model.summary())

    # ==========================================
    # 5. Forecasting & Visualization (3 YEARS AHEAD)
    # ==========================================
    print("\n--- Step 4: Forecasting ---")
    # Forecast the next 12 periods (3 Years, since data is quarterly)
    forecast_steps = 12
    forecast = fitted_model.get_forecast(steps=forecast_steps)
    forecast_mean = forecast.predicted_mean
    conf_int = forecast.conf_int()

    plt.figure(figsize=(12, 6))
    plt.plot(ts_data.index, ts_data, label="Historical CVX Monthly Returns", color="#1f77b4", marker="o")
    plt.plot(ts_data.index, fitted_model.fittedvalues, label="Model Fitted Values", color="green", linestyle="-")
    plt.plot(forecast_mean.index, forecast_mean, label="Forecast (Next 3 Years / 12 Quarters)", color="#d62728", linestyle="--", marker="x")

    plt.fill_between(conf_int.index, 
                    conf_int.iloc[:, 0], 
                    conf_int.iloc[:, 1], 
                    color="#d62728", alpha=0.15, label="95% Confidence Interval")

    plt.title(f"{ticker} Monthly Return - ARIMA Model Forecast (3-Year Horizon)", fontsize=14)
    plt.xlabel("Date", fontsize=12)
    plt.ylabel("Monthly Return (%)", fontsize=12)
    plt.axhline(0, color="black", linewidth=1, linestyle="--")
    plt.legend(loc="upper left")
    plt.grid(True, alpha=0.3)
    plt.show()

# %% [markdown]
# Filtering Data to Determine which stock datasets are viable for training

# %%
def load_data_for_ticker(ticker):
    try:
        # Load Data & Extract Ticker data
        oil_stock_data = oil_industry_data.get(ticker, {})

        # Convert the nested dictionary directly into a Pandas DataFrame
        df = pd.DataFrame.from_dict(oil_stock_data, orient='index')
        df.index = pd.to_datetime(df.index)

        # Sort chronologically and resample to Quarterly
        df = df.sort_index().resample('QE').mean()

        # Drop any columns that are 100% empty, then interpolate missing values
        df = df.dropna(axis=1, how='all')
        df = df.interpolate(method='linear', limit_direction='both')
        return df
    except:
        return None

# %%
def enough_data_points(ticker_data):
    if ticker_data is None:
        return False
    else:
        if len(ticker_data) < 20:
            return False
        else:
            return True

# %%
def check_stationary_category(column_data):
    adf_result = adfuller(column_data)
    kpss_result = kpss(column_data)

    if (adf_result[1] < 0.05 and kpss_result[1] > 0.05):
        # Stationary
        return "stationary"
    elif (adf_result[1] > 0.05 and kpss_result[1] < 0.05):
        # Unit-Root
        return "unit-root"
    else:
        # Neither
        return "other"

# %%
def check_arima_category(ticker_data):
    columns = ["OCF/BOED", "ROA", "CostExpenses/BOED", "Stock/Oil ZScore", "PGR"]

    arima_category = {'stationary': 0, 'unit_root': 0, 'other': 0}
    for indicator in columns:
        arima_type = check_stationary_category(ticker_data[indicator])
        if arima_type == "stationary":
            arima_category['stationary'] += 1
        elif arima_type == "unit-root": 
            arima_category['unit_root'] += 1
        else:
            arima_category['other'] +=1

    return max(arima_category, key=arima_category.get)

# %%
unviable = []
unit_root = []
stationary = []
other = []

# Filter stock data for following criteria:
# Atleast 5 years worth of quarterly data, monthly return is stationary
for stock_ticker in oil_industry_data.keys():
    ticker_data = load_data_for_ticker(stock_ticker)
    if not enough_data_points(ticker_data):
        unviable.append(stock_ticker)
    else:
        if len(ticker_data.columns) == 0:
            unviable.append(stock_ticker)
            continue

        if check_stationary_category(ticker_data["Monthly Return"]) == "stationary":
            arima_category = check_arima_category(ticker_data)

            if arima_category == "stationary":
                stationary.append(stock_ticker)
            elif arima_category == "unit_root":
                unit_root.append(stock_ticker)
            else:
                other.append(stock_ticker)
        else:
            unviable.append(stock_ticker)

# %%
stationary
# Out:
# ['CVX', 'NFG', 'DVN', 'EXE', 'MTDR', 'CNX', 'NOG']

# %%
unit_root
# Out:
# ['RRC', 'TALO']

# %% [markdown]
# SARIMAX Model Training

# %%
p = range(0, 5)
q = range(0, 5)
trainingset_stationary = {}

# %%
def test_model(y_train, X_train, order):
    model = SARIMAX(
        y_train,
        exog=X_train,
        order=order,
        enforce_stationarity=False,
        enforce_invertibility=False
    )
    
    results = model.fit(disp=False)
    return results

# %%
def create_trainingset(ticker_data, window_size=20, test_size=6, min_train_rows=4):
    target_col = "Monthly Return"
    y = ticker_data[target_col]
    X = ticker_data.drop(columns=[target_col, "BOED"]) if "BOED" in ticker_data.columns else ticker_data.drop(columns=[target_col])
    X_lagged = X.shift(1)
    aligned_df = pd.concat([y, X_lagged], axis=1).dropna()
    y_aligned = aligned_df[target_col]
    X_lagged_aligned = aligned_df.drop(columns=[target_col])

    indices = np.array_split(np.arange(len(X_lagged_aligned)), 2)
    X_blocks = [X_lagged_aligned.iloc[idx] for idx in indices]
    y_blocks = [y_aligned.iloc[idx] for idx in indices]

    min_block_size = min(len(idx) for idx in indices)
    if test_size >= min_block_size:
        raise ValueError(f"Not enough data: min block size {min_block_size} <= test_size {test_size}")

    results = []

    for block_id in range(2):
        X_block_test = X_blocks[block_id].iloc[-test_size:]
        y_block_test = y_blocks[block_id].iloc[-test_size:]

        test_start_pos = int(indices[block_id][-test_size])
        train_start_pos = max(0, test_start_pos - window_size)
        X_block_train = X_lagged_aligned.iloc[train_start_pos:test_start_pos]
        y_block_train = y_aligned.iloc[train_start_pos:test_start_pos]

        if len(X_block_train) < min_train_rows:
            raise ValueError(f"Not enough training data in block {block_id}: {len(X_block_train)} rows < min_train_rows {min_train_rows}")

        results.append({
            'X_train': X_block_train, 'X_test': X_block_test,
            'y_train': y_block_train, 'y_test': y_block_test
        })

    return {
        'blocks': results,
        'last_known_financials': X_lagged_aligned.iloc[-1:],
        'y_aligned': y_aligned,
        'X_lagged_aligned': X_lagged_aligned
    }

# %%
def calculate_expected_return(results, y_test, X_test):
    preds = results.get_forecast(steps=len(y_test), exog=X_test).predicted_mean
    returns = []

    for i, pred_value in enumerate(preds):
        if pred_value > 0:
            returns.append(y_test.iloc[i] / 100)
        else:
            returns.append(-y_test.iloc[i] / 100)

    returns_std = np.std(returns) if len(returns) > 0 else 0
    returns_mean = np.mean(returns) if len(returns) > 0 else 0

    sharpe_ratio = returns_mean / returns_std if returns_std > 0 else 0
    return sharpe_ratio

# %%
def train_SARIMAX(ticker, d_val, window_size=20, test_size=6):
    training_split = create_trainingset(ticker, window_size=window_size, test_size=test_size)
    last_known_financials = training_split['last_known_financials']
    training_blocks = training_split['blocks']
    y_aligned = training_split['y_aligned']
    X_lagged_aligned = training_split['X_lagged_aligned']

    best_return = 0
    best_order = None
    weights = np.array([0.25, 0.75])

    for order in itertools.product(p, [d_val], q):
        try:
            ticker_models = [test_model(block['y_train'], block['X_train'], order) for block in training_blocks]
            expected_returns = [calculate_expected_return(ticker_models[i], training_blocks[i]['y_test'], training_blocks[i]['X_test']) for i in range(len(training_blocks))]
            expected_return = sum(np.array(expected_returns) * weights)
            if expected_return > best_return:
                best_return = expected_return
                best_order = order
        except Exception as e:
            print(e)
            continue

    if best_order is None:
        raise ValueError("No valid SARIMAX order found — all orders scored <= 0 or failed")

    print(f"Best SARIMAX order: {best_order} with Expected Return: {best_return:.4f}")

    backtest_data = []
    for block in training_blocks:
        try:
            m = test_model(block['y_train'], block['X_train'], best_order)
            preds = m.get_forecast(steps=len(block['y_test']), exog=block['X_test']).predicted_mean
            preds.index = block['y_test'].index
        except Exception:
            preds = pd.Series([np.nan] * len(block['y_test']), index=block['y_test'].index)
        backtest_data.append({'actual': block['y_test'], 'predicted': preds})

    best_model = test_model(y_aligned, X_lagged_aligned, best_order)

    return last_known_financials, y_aligned, best_model, backtest_data

# %%
def plot_backtest(ticker, backtest_data):
    if not backtest_data:
        print(f"{ticker}: no backtest data available")
        return

    fig, ax = plt.subplots(figsize=(12, 4))
    colors = ['#1f77b4', '#2ca02c', '#9467bd']

    all_actuals = pd.concat([block['actual'] for block in backtest_data])
    actual_min, actual_max = all_actuals.min(), all_actuals.max()
    padding = (actual_max - actual_min) * 0.3 or 5
    ax.set_ylim(actual_min - padding, actual_max + padding)

    for i, block in enumerate(backtest_data):
        ax.plot(block['actual'].index, block['actual'].values,
                color=colors[i], marker='o', label=f'Actual block {i+1}')
        ax.plot(block['predicted'].index, block['predicted'].values,
                color=colors[i], marker='x', linestyle='--', label=f'Predicted block {i+1}')
        ax.axvline(block['actual'].index[0], color='gray', linestyle=':', alpha=0.5)

    ax.axhline(0, color='black', linewidth=0.8, linestyle='--')
    ax.set_title(f'{ticker} — Backtest: Predicted vs Actual Monthly Return')
    ax.set_xlabel('Date')
    ax.set_ylabel('Monthly Return (%)')
    ax.legend(ncol=3, fontsize=8)
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# %%
def SARIMAX_Stock_Analysis(forecast_steps, last_known_financials, y_aligned, fitted_model):
    print(f"--- Forecasting {forecast_steps/4} Years Ahead ---")
    # To forecast the future, SARIMAX needs future Exogenous variables.
    # We will assume that the stock's financials remain exactly the same as the most recent quarter.
    future_X = pd.concat([last_known_financials] * forecast_steps, ignore_index=True)

    # Generate the forecast
    forecast = fitted_model.get_forecast(steps=forecast_steps, exog=future_X)
    forecast_mean = forecast.predicted_mean
    conf_int = forecast.conf_int()

    # Create future dates for plotting
    future_dates = pd.date_range(start=y_aligned.index[-1], periods=forecast_steps + 1, freq='QE')[1:]
    forecast_mean.index = future_dates
    conf_int.index = future_dates

    # ==========================================
    # Visualization
    # ==========================================
    plt.figure(figsize=(12, 6))

    historical_label = f"Historical Monthly Returns"

    # Plot Historical
    plt.plot(y_aligned.index, y_aligned, label=historical_label, color="#1f77b4", marker="o")

    # Plot Fitted Values
    plt.plot(y_aligned.index, fitted_model.fittedvalues, label="Model Fitted Values", color="green", linestyle="-")

    # Plot Forecast
    plt.plot(forecast_mean.index, forecast_mean, label="SARIMAX Forecast (Using Financial Metrics)", color="#ff7f0e", linestyle="--", marker="x")

    # Shade Confidence Interval
    plt.fill_between(conf_int.index, 
                    conf_int.iloc[:, 0], 
                    conf_int.iloc[:, 1], 
                    color="#ff7f0e", alpha=1, label="95% Confidence Interval")

    plt.title("Monthly Return - SARIMAX Model (Financial Metrics Included)", fontsize=14)
    plt.xlabel("Date", fontsize=12)
    plt.ylabel("Monthly Return (%)", fontsize=12)
    plt.axhline(0, color="black", linewidth=1, linestyle="--")
    plt.legend(loc="upper left")
    plt.grid(True, alpha=0.3)
    plt.show()

    # forecast_mean: pd.Series or list of predicted returns (whole-number percentages) for the forecast horizon
    # Returns the total cumulative return over the forecast horizon as a single percentage
    # Convert to decimal
    y_pred = pd.Series(forecast_mean) / 100  
    # Compute cumulative growth over forecast horizon
    cum_return_series = (1 + y_pred).cumprod() - 1  
    # Take the final value → cumulative return for forecast period only
    cumulative_return_pct = cum_return_series.iloc[-1] * 100  
    return cumulative_return_pct

# %% [markdown]
# Train Models and use them to Forecast Returns

# %%
ticker_data_dict_stationary = { x: load_data_for_ticker(x) for x in stationary }
ticker_data_dict_unit_root = { x: load_data_for_ticker(x) for x in unit_root }

# %%
last_known_stationary = {}
y_aligned_stationary = {}
sarimax_model_stationary = {}
backtest_stationary = {}

last_known_unit_root = {}
y_aligned_unit_root = {}
sarimax_model_unit_root = {}
backtest_unit_root = {}

# %%
TEST_SIZE = 6
WINDOW_SIZE = 20

for x in ticker_data_dict_stationary.keys():
    print(x)
    try:
        last_known_stationary[x], y_aligned_stationary[x], sarimax_model_stationary[x], backtest_stationary[x] = train_SARIMAX(ticker_data_dict_stationary[x], 0, window_size=WINDOW_SIZE, test_size=TEST_SIZE)
        plot_backtest(x, backtest_stationary[x])
    except ValueError as e:
        print(f"  Skipping {x}: {e}")

for x in ticker_data_dict_unit_root.keys():
    print(x)
    try:
        last_known_unit_root[x], y_aligned_unit_root[x], sarimax_model_unit_root[x], backtest_unit_root[x] = train_SARIMAX(ticker_data_dict_unit_root[x], 1, window_size=WINDOW_SIZE, test_size=TEST_SIZE)
        plot_backtest(x, backtest_unit_root[x])
    except ValueError as e:
        print(f"  Skipping {x}: {e}")
# Out:
# CVX
# Best SARIMAX order: (3, 0, 3) with Expected Return: 0.6829
# NFG
# Best SARIMAX order: (4, 0, 2) with Expected Return: 0.4084
# DVN
# Best SARIMAX order: (4, 0, 2) with Expected Return: 0.8179
# EXE
# Best SARIMAX order: (1, 0, 4) with Expected Return: 1.1238
# MTDR
# Best SARIMAX order: (0, 0, 4) with Expected Return: 0.7269
# CNX
# Best SARIMAX order: (4, 0, 4) with Expected Return: 0.2823
# NOG
# Best SARIMAX order: (4, 0, 0) with Expected Return: 0.6788
# RRC
# Best SARIMAX order: (2, 1, 4) with Expected Return: 0.3356
# TALO
# Best SARIMAX order: (3, 1, 0) with Expected Return: 0.1436

# %%
cumulative_returns = {}
sarimax_models = {
    **sarimax_model_stationary,
    **sarimax_model_unit_root
}
all_stocks = [x for x in stationary + unit_root if x in sarimax_models]

last_financials_vals = {
    **last_known_stationary,
    **last_known_unit_root
}

y_aligned_vals = {
    **y_aligned_stationary,
    **y_aligned_unit_root
}



for stock_ticker in all_stocks:
    try:
        print(stock_ticker)
        y_aligned = y_aligned_vals[stock_ticker] 
        sarimax_model = sarimax_models[stock_ticker]
        last_known = last_financials_vals[stock_ticker]
        cumulative_returns[stock_ticker] = SARIMAX_Stock_Analysis(2, last_known, y_aligned, sarimax_model)
    except Exception as e:
        print(e)
# Out:
# CVX
# --- Forecasting 0.5 Years Ahead ---
# NFG
# --- Forecasting 0.5 Years Ahead ---
# DVN
# --- Forecasting 0.5 Years Ahead ---
# EXE
# --- Forecasting 0.5 Years Ahead ---
# MTDR
# --- Forecasting 0.5 Years Ahead ---
# CNX
# --- Forecasting 0.5 Years Ahead ---
# NOG
# --- Forecasting 0.5 Years Ahead ---
# RRC
# --- Forecasting 0.5 Years Ahead ---
# TALO
# --- Forecasting 0.5 Years Ahead ---

# %% [markdown]
# Compute Stock Ranking

# %%
cumulative_returns
# Out:
# {'CVX': np.float64(-9.782844959057279),
#  'NFG': np.float64(-1.7115997591023668),
#  'DVN': np.float64(231.03186668105934),
#  'EXE': np.float64(-17.042884757229103),
#  'MTDR': np.float64(-26.144099531563803),
#  'CNX': np.float64(-16.35563455428982),
#  'NOG': np.float64(9.398255663402821),
#  'RRC': np.float64(-11.001570824254813),
#  'TALO': np.float64(26.974634083854497)}

# %%
df_returns = pd.DataFrame(list(cumulative_returns.items()), columns=["Ticker", "Cumulative Return (%)"])
df_sorted = df_returns.sort_values(by="Cumulative Return (%)", ascending=False).reset_index(drop=True)
df_sorted
# Out:
#   Ticker  Cumulative Return (%)
# 0    DVN             231.031867
# 1   TALO              26.974634
# 2    NOG               9.398256
# 3    NFG              -1.711600
# 4    CVX              -9.782845
# 5    RRC             -11.001571
# 6    CNX             -16.355635
# 7    EXE             -17.042885
# 8   MTDR             -26.144100
